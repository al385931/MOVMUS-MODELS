# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, MaxPooling1D, GlobalAveragePooling1D, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import compute_class_weight
from sklearn.utils import class_weight
from tensorflow.keras.metrics import Precision, Recall, AUC, SparseCategoricalAccuracy
from tensorflow.keras.regularizers import l2

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import movmus as mm

import json
import os

# %% [markdown]
# # task context model

# %% [markdown]
# #### opening and transforming metadata

# %%
train_data, val_data, test_data = mm.load_data_npz('EMG_1000_data.npz')
# Out:
# shape of training data: (2720, 1000, 7)
# shape of validation data: (502, 1000, 7)
# shape of test data: (661, 1000, 7)

# %%
train_labels, val_labels, test_labels = mm.load_data_npz('labels.npz')
# Out:
# shape of training data: (2720, 2)
# shape of validation data: (502, 2)
# shape of test data: (661, 2)

# %% [markdown]
# #### context with shape

# %%
train_task_context = mm.load_metadata_npz('task_context_train.npz')
val_task_context = mm.load_metadata_npz('task_context_val.npz')
test_task_context = mm.load_metadata_npz('task_context_test.npz')

print('Context data shapes:', train_task_context.shape, val_task_context.shape, test_task_context.shape)
# Out:
# Context data shapes: (2720, 25) (502, 25) (661, 25)

# %%
train_task_context = train_task_context.iloc[:, 1:]
val_task_context = val_task_context.iloc[:, 1:]
test_task_context = test_task_context.iloc[:, 1:]
print('Context data shapes:', train_task_context.shape, val_task_context.shape, test_task_context.shape)
# Out:
# Context data shapes: (2720, 24) (502, 24) (661, 24)

# %% [markdown]
# #### context without shape

# %%
train_task_context = mm.load_metadata_npz('task_no_shape_context_train.npz')
val_task_context = mm.load_metadata_npz('task_no_shape_context_val.npz')
test_task_context = mm.load_metadata_npz('task_no_shape_context_test.npz')

print('Context data shapes:', train_task_context.shape, val_task_context.shape, test_task_context.shape)
# Out:
# Context data shapes: (2720, 6) (502, 6) (661, 6)

# %% [markdown]
# ### model parameters

# %%
batch_size = 68
epochs = 300
num_samples = len(train_data)  # Number of training samples
print('Number of training samples:', num_samples)
# Out:
# Number of training samples: 2720

# %%
# Define the learning rate schedule
initial_learning_rate = 0.001
decay_steps = (num_samples/batch_size)*epochs  # 2752 samples/ 86 bs = 32 --> 32 * 250 epochs = 8000 steps
print("Decay steps:", decay_steps)
alpha = 0.01 

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    alpha=alpha
)
# Out:
# Decay steps: 12000.0

# %%
from tensorflow.keras.callbacks import Callback

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = tf.keras.backend.get_value(self.model.optimizer.learning_rate)
        print(f" - lr: {lr}")

# %% [markdown]
# DEFINING THE ENTRIES

# %%
#DATA EMG
X_trainEMG = train_data
print('emg data shape: ' + str(X_trainEMG.shape))
X_valEMG = val_data
print('emg val data shape: ' + str(X_valEMG.shape))
print('')
#DATA CONTEXT
X_trainContext = train_task_context.to_numpy()
print('emg context shape: ' + str(X_trainContext.shape))

X_valContext = val_task_context.to_numpy()
print('emg val context shape: ' + str(X_valContext.shape))
print('')
#LABELS
y_trainEMG = train_labels
y_valEMG = val_labels
print('emg labels shape: ' + str(y_trainEMG.shape))
print('emg val labels shape: ' + str(y_valEMG.shape))
# Out:
# emg data shape: (2720, 1000, 7)
# emg val data shape: (502, 1000, 7)
#
# emg context shape: (2720, 6)
# emg val context shape: (502, 6)
#
# emg labels shape: (2720, 2)
# emg val labels shape: (502, 2)

# %% [markdown]
# ### model creation

# %% [markdown]
# Name of the model:
# - S_C : subject context
# - T_C : task context
#
# '+'
#
# - CUSTOM : from parent EMG model M_20
# - BASE : from parent EMG model M_28
#
# '+'
#
# - Model number

# %%
model_name = 'BASE_TASK_CONTEXT_MODEL_6_no_shape'
model_folder = '.\\MODELS_TC'
plot_folder = '.\\PLOTS_TC'

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv1D, BatchNormalization, MaxPooling1D, GlobalAveragePooling1D, 
    Dropout, Dense, Input, concatenate
)
from tensorflow.keras.models import Model

# Define the EMG signal branch
emg_input = Input(shape=(1000, 7), name='emg_input')
# try 16 32 or 32 32
x = Conv1D(filters=16, kernel_size=5, padding='valid', activation='relu')(emg_input)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=32, kernel_size=5, padding='valid', activation='relu')(x)
x = BatchNormalization()(x)
x = GlobalAveragePooling1D()(x)
#x = Dropout(0.2)(x)

# Define the context branch
context_input = Input(shape=(6,), name='context_input') 

y = Dense(64, activation='relu')(context_input)
#y = Dense(64, activation='relu')(y)
y= BatchNormalization()(y)
#y = Dense(128, activation='relu')(context_input) #if CUSTOM LAYERS
#y = Dropout(0.1)(y)

#add bn possibly add dropout
y = Dense(32, activation='relu')(y)
#y = Dense(64, activation='relu')(y) #if CUSTOM LAYERS
#y = BatchNormalization()(y)
#y = Dropout(0.2)(y)

#add bn possibly add dropout

# Concatenate the branches
combined = concatenate([x, y])

# custom layers
#z = Dense(64, activation='relu',)(combined)
#z = BatchNormalization()(z)

# Add final layers
z = Dropout(0.2)(combined)
#z = Dense(64, activation='relu', kernel_regularizer=l2(0.02))(z)
z = Dense(32, activation='relu', kernel_regularizer=l2(0.02))(z)
#z = Dense(16, activation='relu', kernel_regularizer=l2(0.02))(z)
output = Dense(2, activation='softmax')(z)

# Create the model
model = Model(inputs=[emg_input, context_input], outputs=output)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=lr_schedule),
    metrics=['accuracy', 'Precision', 'Recall', 'AUC'] 
)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ emg_input           │ (None, 1000, 7)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 996, 16)   │        576 │ emg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 996, 16)   │         64 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 498, 16)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 494, 32)   │      2,592 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │        448 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 494, 32)   │        128 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 32)        │      2,080 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64)        │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 32)        │      2,080 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 2)         │         66 │ dense_10[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,290 (32.38 KB)
#  Trainable params: 8,066 (31.51 KB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# ### training

# %%
start_time = time.time()
history = model.fit(
    x=[X_trainEMG, X_trainContext],  # Input data: EMG and context
    y=y_trainEMG,                    # Labels
    validation_data=([X_valEMG, X_valContext], y_valEMG),  # Validation data
    epochs=epochs,                        
    batch_size=batch_size,                    
    callbacks=[
        LearningRateLogger()#,                       
        #tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    ]
)
end_time = time.time()
# Out:
# Epoch 1/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7103 - Precision: 0.6446 - Recall: 0.6446 - accuracy: 0.6446 - loss: 1.3900 - lr: 0.0009999729227274656
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - AUC: 0.7128 - Precision: 0.6469 - Recall: 0.6469 - accuracy: 0.6469 - loss: 1.3867 - val_AUC: 0.8205 - val_Precision: 0.7689 - val_Recall: 0.7689 - val_accuracy: 0.7689 - val_loss: 1.2057
# Epoch 2/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8673 - Precision: 0.7988 - Recall: 0.7988 - accuracy: 0.7988 - loss: 0.9861 - lr: 0.0009998914320021868
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8681 - Precision: 0.7997 - Recall: 0.7997 - accuracy: 0.7997 - loss: 0.9824 - val_AUC: 0.8544 - val_Precision: 0.7769 - val_Recall: 0.7769 - val_accuracy: 0.7769 - val_loss: 0.9406
# Epoch 3/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9108 - Precision: 0.8498 - Recall: 0.8498 - accuracy: 0.8498 - loss: 0.7363 - lr: 0.0009997556917369366
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9108 - Precision: 0.8498 - Recall: 0.8498 - accuracy: 0.8498 - loss: 0.7355 - val_AUC: 0.8738 - val_Precision: 0.7789 - val_Recall: 0.7789 - val_accuracy: 0.7789 - val_loss: 0.7497
# Epoch 4/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9116 - Precision: 0.8455 - Recall: 0.8455 - accuracy: 0.8455 - loss: 0.6132 - lr: 0.0009995659347623587
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9121 - Precision: 0.8460 - Recall: 0.8460 - accuracy: 0.8460 - loss: 0.6111 - val_AUC: 0.8944 - val_Precision: 0.8406 - val_Recall: 0.8406 - val_accuracy: 0.8406 - val_loss: 0.6258
# Epoch 5/300
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9251 - Precision: 0.8625 - Recall: 0.8625 - accuracy: 0.8625 - loss: 0.5064 - lr: 0.0009993216954171658
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9252 - Precision: 0.8619 - Recall: 0.8619 - accuracy: 0.8619 - loss: 0.5045 - val_AUC: 0.8871 - val_Precision: 0.8207 - val_Recall: 0.8207 - val_accuracy: 0.8207 - val_loss: 0.5669
# Epoch 6/300
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9317 - Precision: 0.8670 - Recall: 0.8670 - accuracy: 0.8670 - loss: 0.4425 - lr: 0.0009990233229473233
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9319 - Precision: 0.8672 - Recall: 0.8672 - accuracy: 0.8672 - loss: 0.4409 - val_AUC: 0.8851 - val_Precision: 0.7829 - val_Recall: 0.7829 - val_accuracy: 0.7829 - val_loss: 0.5436
# Epoch 7/300
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9400 - Precision: 0.8689 - Recall: 0.8689 - accuracy: 0.8689 - loss: 0.3928 - lr: 0.0009986707009375095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.9393 - Precision: 0.8681 - Recall: 0.8681 - accuracy: 0.8681 - loss: 0.3937 - val_AUC: 0.9080 - val_Precision: 0.8406 - val_Recall: 0.8406 - val_accuracy: 0.8406 - val_loss: 0.4719
# Epoch 8/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.9424 - Precision: 0.8849 - Recall: 0.8849 - accuracy: 0.8849 - loss: 0.3670 - lr: 0.0009982639458030462
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.9424 - Precision: 0.8847 - Recall: 0.8847 - accuracy: 0.8847 - loss: 0.3670 - val_AUC: 0.9121 - val_Precision: 0.8606 - val_Recall: 0.8606 - val_accuracy: 0.8606 - val_loss: 0.4447
# Epoch 9/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9442 - Precision: 0.8802 - Recall: 0.8802 - accuracy: 0.8802 - loss: 0.3511 - lr: 0.0009978031739592552
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.9440 - Precision: 0.8795 - Recall: 0.8795 - accuracy: 0.8795 - loss: 0.3514 - val_AUC: 0.9169 - val_Precision: 0.8187 - val_Recall: 0.8187 - val_accuracy: 0.8187 - val_loss: 0.4240
# Epoch 10/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9427 - Precision: 0.8746 - Recall: 0.8746 - accuracy: 0.8746 - loss: 0.3475 - lr: 0.0009972883854061365
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9428 - Precision: 0.8746 - Recall: 0.8746 - accuracy: 0.8746 - loss: 0.3472 - val_AUC: 0.9211 - val_Precision: 0.8566 - val_Recall: 0.8566 - val_accuracy: 0.8566 - val_loss: 0.4020
# Epoch 11/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9449 - Precision: 0.8796 - Recall: 0.8796 - accuracy: 0.8796 - loss: 0.3319 - lr: 0.0009967195801436901
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9451 - Precision: 0.8796 - Recall: 0.8796 - accuracy: 0.8796 - loss: 0.3315 - val_AUC: 0.9261 - val_Precision: 0.8586 - val_Recall: 0.8586 - val_accuracy: 0.8586 - val_loss: 0.3861
# Epoch 12/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9473 - Precision: 0.8830 - Recall: 0.8830 - accuracy: 0.8830 - loss: 0.3234 - lr: 0.0009960968745872378
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9473 - Precision: 0.8830 - Recall: 0.8830 - accuracy: 0.8830 - loss: 0.3233 - val_AUC: 0.9266 - val_Precision: 0.8406 - val_Recall: 0.8406 - val_accuracy: 0.8406 - val_loss: 0.3865
# Epoch 13/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9469 - Precision: 0.8699 - Recall: 0.8699 - accuracy: 0.8699 - loss: 0.3242 - lr: 0.0009954202687367797
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9471 - Precision: 0.8704 - Recall: 0.8704 - accuracy: 0.8704 - loss: 0.3236 - val_AUC: 0.9331 - val_Precision: 0.8386 - val_Recall: 0.8386 - val_accuracy: 0.8386 - val_loss: 0.3680
# Epoch 14/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9559 - Precision: 0.8912 - Recall: 0.8912 - accuracy: 0.8912 - loss: 0.2964 - lr: 0.0009946898790076375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9558 - Precision: 0.8908 - Recall: 0.8908 - accuracy: 0.8908 - loss: 0.2968 - val_AUC: 0.9471 - val_Precision: 0.8665 - val_Recall: 0.8665 - val_accuracy: 0.8665 - val_loss: 0.3318
# Epoch 15/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9512 - Precision: 0.8848 - Recall: 0.8848 - accuracy: 0.8848 - loss: 0.3090 - lr: 0.000993905821815133
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9513 - Precision: 0.8848 - Recall: 0.8848 - accuracy: 0.8848 - loss: 0.3089 - val_AUC: 0.9360 - val_Precision: 0.8705 - val_Recall: 0.8705 - val_accuracy: 0.8705 - val_loss: 0.3525
# Epoch 16/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9446 - Precision: 0.8709 - Recall: 0.8709 - accuracy: 0.8709 - loss: 0.3199 - lr: 0.0009930680971592665
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9448 - Precision: 0.8712 - Recall: 0.8712 - accuracy: 0.8712 - loss: 0.3194 - val_AUC: 0.9415 - val_Precision: 0.8725 - val_Recall: 0.8725 - val_accuracy: 0.8725 - val_loss: 0.3439
# Epoch 17/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9462 - Precision: 0.8748 - Recall: 0.8748 - accuracy: 0.8748 - loss: 0.3165 - lr: 0.0009921768214553595
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9464 - Precision: 0.8751 - Recall: 0.8751 - accuracy: 0.8751 - loss: 0.3161 - val_AUC: 0.9474 - val_Precision: 0.8725 - val_Recall: 0.8725 - val_accuracy: 0.8725 - val_loss: 0.3230
# Epoch 18/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9586 - Precision: 0.8897 - Recall: 0.8897 - accuracy: 0.8897 - loss: 0.2813 - lr: 0.0009912322275340557
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9584 - Precision: 0.8891 - Recall: 0.8891 - accuracy: 0.8891 - loss: 0.2820 - val_AUC: 0.9287 - val_Precision: 0.8446 - val_Recall: 0.8446 - val_accuracy: 0.8446 - val_loss: 0.3683
# Epoch 19/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9543 - Precision: 0.8854 - Recall: 0.8854 - accuracy: 0.8854 - loss: 0.2902 - lr: 0.0009902341989800334
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9543 - Precision: 0.8858 - Recall: 0.8858 - accuracy: 0.8858 - loss: 0.2900 - val_AUC: 0.9442 - val_Precision: 0.8785 - val_Recall: 0.8785 - val_accuracy: 0.8785 - val_loss: 0.3313
# Epoch 20/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9585 - Precision: 0.8843 - Recall: 0.8843 - accuracy: 0.8843 - loss: 0.2862 - lr: 0.000989183085039258
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9585 - Precision: 0.8845 - Recall: 0.8845 - accuracy: 0.8845 - loss: 0.2859 - val_AUC: 0.9449 - val_Precision: 0.8625 - val_Recall: 0.8625 - val_accuracy: 0.8625 - val_loss: 0.3298
# Epoch 21/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9590 - Precision: 0.8923 - Recall: 0.8923 - accuracy: 0.8923 - loss: 0.2801 - lr: 0.0009880787692964077
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9590 - Precision: 0.8922 - Recall: 0.8922 - accuracy: 0.8922 - loss: 0.2802 - val_AUC: 0.9267 - val_Precision: 0.8506 - val_Recall: 0.8506 - val_accuracy: 0.8506 - val_loss: 0.3770
# Epoch 22/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9627 - Precision: 0.9002 - Recall: 0.9002 - accuracy: 0.9002 - loss: 0.2659 - lr: 0.000986921600997448
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9627 - Precision: 0.8999 - Recall: 0.8999 - accuracy: 0.8999 - loss: 0.2661 - val_AUC: 0.9398 - val_Precision: 0.8685 - val_Recall: 0.8685 - val_accuracy: 0.8685 - val_loss: 0.3463
# Epoch 23/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9654 - Precision: 0.9019 - Recall: 0.9019 - accuracy: 0.9019 - loss: 0.2614 - lr: 0.000985711463727057
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9650 - Precision: 0.9011 - Recall: 0.9011 - accuracy: 0.9011 - loss: 0.2624 - val_AUC: 0.9374 - val_Precision: 0.8566 - val_Recall: 0.8566 - val_accuracy: 0.8566 - val_loss: 0.3525
# Epoch 24/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9637 - Precision: 0.8963 - Recall: 0.8963 - accuracy: 0.8963 - loss: 0.2694 - lr: 0.0009844487067312002
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9636 - Precision: 0.8961 - Recall: 0.8961 - accuracy: 0.8961 - loss: 0.2694 - val_AUC: 0.9166 - val_Precision: 0.8506 - val_Recall: 0.8506 - val_accuracy: 0.8506 - val_loss: 0.4149
# Epoch 25/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9618 - Precision: 0.9007 - Recall: 0.9007 - accuracy: 0.9007 - loss: 0.2660 - lr: 0.0009831333300098777
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9617 - Precision: 0.8998 - Recall: 0.8998 - accuracy: 0.8998 - loss: 0.2665 - val_AUC: 0.9370 - val_Precision: 0.8665 - val_Recall: 0.8665 - val_accuracy: 0.8665 - val_loss: 0.3661
# Epoch 26/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9688 - Precision: 0.9050 - Recall: 0.9050 - accuracy: 0.9050 - loss: 0.2475 - lr: 0.0009817654499784112
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9682 - Precision: 0.9046 - Recall: 0.9046 - accuracy: 0.9046 - loss: 0.2490 - val_AUC: 0.9044 - val_Precision: 0.8108 - val_Recall: 0.8108 - val_accuracy: 0.8108 - val_loss: 0.4559
# Epoch 27/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9600 - Precision: 0.8857 - Recall: 0.8857 - accuracy: 0.8857 - loss: 0.2772 - lr: 0.0009803454158827662
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9602 - Precision: 0.8860 - Recall: 0.8860 - accuracy: 0.8860 - loss: 0.2767 - val_AUC: 0.9493 - val_Precision: 0.8845 - val_Recall: 0.8845 - val_accuracy: 0.8845 - val_loss: 0.3269
# Epoch 28/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9681 - Precision: 0.9035 - Recall: 0.9035 - accuracy: 0.9035 - loss: 0.2510 - lr: 0.0009788732277229428
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.9679 - Precision: 0.9031 - Recall: 0.9031 - accuracy: 0.9031 - loss: 0.2513 - val_AUC: 0.9517 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3171
# Epoch 29/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9668 - Precision: 0.9036 - Recall: 0.9036 - accuracy: 0.9036 - loss: 0.2537 - lr: 0.0009773490019142628
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9667 - Precision: 0.9038 - Recall: 0.9038 - accuracy: 0.9038 - loss: 0.2539 - val_AUC: 0.9300 - val_Precision: 0.8466 - val_Recall: 0.8466 - val_accuracy: 0.8466 - val_loss: 0.3749
# Epoch 30/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9519 - Precision: 0.8802 - Recall: 0.8802 - accuracy: 0.8802 - loss: 0.2926 - lr: 0.0009757730294950306
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9522 - Precision: 0.8808 - Recall: 0.8808 - accuracy: 0.8808 - loss: 0.2918 - val_AUC: 0.9285 - val_Precision: 0.8426 - val_Recall: 0.8426 - val_accuracy: 0.8426 - val_loss: 0.3867
# Epoch 31/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9703 - Precision: 0.9011 - Recall: 0.9011 - accuracy: 0.9011 - loss: 0.2457 - lr: 0.0009741454268805683
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9700 - Precision: 0.9010 - Recall: 0.9010 - accuracy: 0.9010 - loss: 0.2462 - val_AUC: 0.9367 - val_Precision: 0.8645 - val_Recall: 0.8645 - val_accuracy: 0.8645 - val_loss: 0.3699
# Epoch 32/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9676 - Precision: 0.9056 - Recall: 0.9056 - accuracy: 0.9056 - loss: 0.2512 - lr: 0.0009724663104861975
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9675 - Precision: 0.9051 - Recall: 0.9051 - accuracy: 0.9051 - loss: 0.2515 - val_AUC: 0.9421 - val_Precision: 0.8725 - val_Recall: 0.8725 - val_accuracy: 0.8725 - val_loss: 0.3599
# Epoch 33/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9722 - Precision: 0.9050 - Recall: 0.9050 - accuracy: 0.9050 - loss: 0.2370 - lr: 0.0009707360295578837
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9721 - Precision: 0.9049 - Recall: 0.9049 - accuracy: 0.9049 - loss: 0.2373 - val_AUC: 0.9423 - val_Precision: 0.8625 - val_Recall: 0.8625 - val_accuracy: 0.8625 - val_loss: 0.3542
# Epoch 34/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9609 - Precision: 0.8994 - Recall: 0.8994 - accuracy: 0.8994 - loss: 0.2700 - lr: 0.0009689545840956271
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9613 - Precision: 0.8996 - Recall: 0.8996 - accuracy: 0.8996 - loss: 0.2688 - val_AUC: 0.9484 - val_Precision: 0.8924 - val_Recall: 0.8924 - val_accuracy: 0.8924 - val_loss: 0.3305
# Epoch 35/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9745 - Precision: 0.9174 - Recall: 0.9174 - accuracy: 0.9174 - loss: 0.2271 - lr: 0.0009671223815530539
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9743 - Precision: 0.9170 - Recall: 0.9170 - accuracy: 0.9170 - loss: 0.2277 - val_AUC: 0.9419 - val_Precision: 0.8944 - val_Recall: 0.8944 - val_accuracy: 0.8944 - val_loss: 0.3860
# Epoch 36/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9664 - Precision: 0.9010 - Recall: 0.9010 - accuracy: 0.9010 - loss: 0.2537 - lr: 0.0009652393637225032
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9665 - Precision: 0.9011 - Recall: 0.9011 - accuracy: 0.9011 - loss: 0.2535 - val_AUC: 0.9438 - val_Precision: 0.8785 - val_Recall: 0.8785 - val_accuracy: 0.8785 - val_loss: 0.3509
# Epoch 37/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9680 - Precision: 0.9098 - Recall: 0.9098 - accuracy: 0.9098 - loss: 0.2440 - lr: 0.0009633059962652624
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9681 - Precision: 0.9097 - Recall: 0.9097 - accuracy: 0.9097 - loss: 0.2438 - val_AUC: 0.9461 - val_Precision: 0.8645 - val_Recall: 0.8645 - val_accuracy: 0.8645 - val_loss: 0.3613
# Epoch 38/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9659 - Precision: 0.9068 - Recall: 0.9068 - accuracy: 0.9068 - loss: 0.2518 - lr: 0.0009613222791813314
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9660 - Precision: 0.9067 - Recall: 0.9067 - accuracy: 0.9067 - loss: 0.2515 - val_AUC: 0.9546 - val_Precision: 0.8825 - val_Recall: 0.8825 - val_accuracy: 0.8825 - val_loss: 0.3117
# Epoch 39/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9754 - Precision: 0.9140 - Recall: 0.9140 - accuracy: 0.9140 - loss: 0.2245 - lr: 0.0009592885617166758
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9750 - Precision: 0.9138 - Recall: 0.9138 - accuracy: 0.9138 - loss: 0.2253 - val_AUC: 0.9568 - val_Precision: 0.8884 - val_Recall: 0.8884 - val_accuracy: 0.8884 - val_loss: 0.3001
# Epoch 40/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9715 - Precision: 0.9115 - Recall: 0.9115 - accuracy: 0.9115 - loss: 0.2374 - lr: 0.0009572049602866173
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9714 - Precision: 0.9114 - Recall: 0.9114 - accuracy: 0.9114 - loss: 0.2376 - val_AUC: 0.9233 - val_Precision: 0.8486 - val_Recall: 0.8486 - val_accuracy: 0.8486 - val_loss: 0.4266
# Epoch 41/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9699 - Precision: 0.9047 - Recall: 0.9047 - accuracy: 0.9047 - loss: 0.2413 - lr: 0.0009550719405524433
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9700 - Precision: 0.9053 - Recall: 0.9053 - accuracy: 0.9053 - loss: 0.2409 - val_AUC: 0.9522 - val_Precision: 0.8984 - val_Recall: 0.8984 - val_accuracy: 0.8984 - val_loss: 0.3305
# Epoch 42/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9712 - Precision: 0.9010 - Recall: 0.9010 - accuracy: 0.9010 - loss: 0.2372 - lr: 0.0009528895025141537
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9708 - Precision: 0.9008 - Recall: 0.9008 - accuracy: 0.9008 - loss: 0.2382 - val_AUC: 0.9432 - val_Precision: 0.9024 - val_Recall: 0.9024 - val_accuracy: 0.9024 - val_loss: 0.3760
# Epoch 43/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9714 - Precision: 0.9116 - Recall: 0.9116 - accuracy: 0.9116 - loss: 0.2350 - lr: 0.0009506578790023923
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9713 - Precision: 0.9114 - Recall: 0.9114 - accuracy: 0.9114 - loss: 0.2351 - val_AUC: 0.9532 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3223
# Epoch 44/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9616 - Precision: 0.8991 - Recall: 0.8991 - accuracy: 0.8991 - loss: 0.2619 - lr: 0.0009483773610554636
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9623 - Precision: 0.9000 - Recall: 0.9000 - accuracy: 0.9000 - loss: 0.2601 - val_AUC: 0.9514 - val_Precision: 0.8725 - val_Recall: 0.8725 - val_accuracy: 0.8725 - val_loss: 0.3348
# Epoch 45/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9749 - Precision: 0.9161 - Recall: 0.9161 - accuracy: 0.9161 - loss: 0.2232 - lr: 0.0009460482397116721
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9749 - Precision: 0.9165 - Recall: 0.9165 - accuracy: 0.9165 - loss: 0.2230 - val_AUC: 0.9493 - val_Precision: 0.8785 - val_Recall: 0.8785 - val_accuracy: 0.8785 - val_loss: 0.3469
# Epoch 46/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9747 - Precision: 0.9120 - Recall: 0.9120 - accuracy: 0.9120 - loss: 0.2196 - lr: 0.0009436708060093224
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9743 - Precision: 0.9118 - Recall: 0.9118 - accuracy: 0.9118 - loss: 0.2209 - val_AUC: 0.9475 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3434
# Epoch 47/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9653 - Precision: 0.9019 - Recall: 0.9019 - accuracy: 0.9019 - loss: 0.2460 - lr: 0.0009412452345713973
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9656 - Precision: 0.9025 - Recall: 0.9025 - accuracy: 0.9025 - loss: 0.2453 - val_AUC: 0.9583 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3046
# Epoch 48/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9725 - Precision: 0.9107 - Recall: 0.9107 - accuracy: 0.9107 - loss: 0.2306 - lr: 0.0009387718164362013
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9725 - Precision: 0.9111 - Recall: 0.9111 - accuracy: 0.9111 - loss: 0.2303 - val_AUC: 0.9460 - val_Precision: 0.8785 - val_Recall: 0.8785 - val_accuracy: 0.8785 - val_loss: 0.3650
# Epoch 49/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9722 - Precision: 0.9176 - Recall: 0.9176 - accuracy: 0.9176 - loss: 0.2306 - lr: 0.0009362508426420391
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9722 - Precision: 0.9175 - Recall: 0.9175 - accuracy: 0.9175 - loss: 0.2305 - val_AUC: 0.9555 - val_Precision: 0.8924 - val_Recall: 0.8924 - val_accuracy: 0.8924 - val_loss: 0.3268
# Epoch 50/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9753 - Precision: 0.9178 - Recall: 0.9178 - accuracy: 0.9178 - loss: 0.2166 - lr: 0.000933682662434876
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9753 - Precision: 0.9175 - Recall: 0.9175 - accuracy: 0.9175 - loss: 0.2168 - val_AUC: 0.9528 - val_Precision: 0.8884 - val_Recall: 0.8884 - val_accuracy: 0.8884 - val_loss: 0.3347
# Epoch 51/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9725 - Precision: 0.9129 - Recall: 0.9129 - accuracy: 0.9129 - loss: 0.2278 - lr: 0.0009310673922300339
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9727 - Precision: 0.9132 - Recall: 0.9132 - accuracy: 0.9132 - loss: 0.2273 - val_AUC: 0.9501 - val_Precision: 0.8924 - val_Recall: 0.8924 - val_accuracy: 0.8924 - val_loss: 0.3418
# Epoch 52/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9750 - Precision: 0.9178 - Recall: 0.9178 - accuracy: 0.9178 - loss: 0.2131 - lr: 0.0009284053812734783
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9751 - Precision: 0.9180 - Recall: 0.9180 - accuracy: 0.9180 - loss: 0.2130 - val_AUC: 0.9537 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3337
# Epoch 53/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9768 - Precision: 0.9227 - Recall: 0.9227 - accuracy: 0.9227 - loss: 0.2142 - lr: 0.0009256969206035137
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9768 - Precision: 0.9226 - Recall: 0.9226 - accuracy: 0.9226 - loss: 0.2143 - val_AUC: 0.9454 - val_Precision: 0.8884 - val_Recall: 0.8884 - val_accuracy: 0.8884 - val_loss: 0.3631
# Epoch 54/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9744 - Precision: 0.9214 - Recall: 0.9214 - accuracy: 0.9214 - loss: 0.2204 - lr: 0.0009229423594661057
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.9744 - Precision: 0.9213 - Recall: 0.9213 - accuracy: 0.9213 - loss: 0.2204 - val_AUC: 0.9532 - val_Precision: 0.8825 - val_Recall: 0.8825 - val_accuracy: 0.8825 - val_loss: 0.3435
# Epoch 55/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9748 - Precision: 0.9077 - Recall: 0.9077 - accuracy: 0.9077 - loss: 0.2219 - lr: 0.0009201419306918979
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9750 - Precision: 0.9084 - Recall: 0.9084 - accuracy: 0.9084 - loss: 0.2212 - val_AUC: 0.9478 - val_Precision: 0.8685 - val_Recall: 0.8685 - val_accuracy: 0.8685 - val_loss: 0.3691
# Epoch 56/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9776 - Precision: 0.9128 - Recall: 0.9128 - accuracy: 0.9128 - loss: 0.2120 - lr: 0.0009172960999421775
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9776 - Precision: 0.9129 - Recall: 0.9129 - accuracy: 0.9129 - loss: 0.2121 - val_AUC: 0.9565 - val_Precision: 0.8805 - val_Recall: 0.8805 - val_accuracy: 0.8805 - val_loss: 0.3210
# Epoch 57/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9762 - Precision: 0.9231 - Recall: 0.9231 - accuracy: 0.9231 - loss: 0.2118 - lr: 0.0009144049254246056
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9763 - Precision: 0.9231 - Recall: 0.9231 - accuracy: 0.9231 - loss: 0.2117 - val_AUC: 0.9447 - val_Precision: 0.8765 - val_Recall: 0.8765 - val_accuracy: 0.8765 - val_loss: 0.3531
# Epoch 58/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9767 - Precision: 0.9197 - Recall: 0.9197 - accuracy: 0.9197 - loss: 0.2079 - lr: 0.0009114688728004694
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9768 - Precision: 0.9195 - Recall: 0.9195 - accuracy: 0.9195 - loss: 0.2082 - val_AUC: 0.9574 - val_Precision: 0.9024 - val_Recall: 0.9024 - val_accuracy: 0.9024 - val_loss: 0.3113
# Epoch 59/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9800 - Precision: 0.9201 - Recall: 0.9201 - accuracy: 0.9201 - loss: 0.2011 - lr: 0.0009084882913157344
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9799 - Precision: 0.9201 - Recall: 0.9201 - accuracy: 0.9201 - loss: 0.2013 - val_AUC: 0.9504 - val_Precision: 0.8944 - val_Recall: 0.8944 - val_accuracy: 0.8944 - val_loss: 0.3549
# Epoch 60/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9798 - Precision: 0.9302 - Recall: 0.9302 - accuracy: 0.9302 - loss: 0.2022 - lr: 0.0009054634138010442
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9798 - Precision: 0.9300 - Recall: 0.9300 - accuracy: 0.9300 - loss: 0.2024 - val_AUC: 0.9512 - val_Precision: 0.8865 - val_Recall: 0.8865 - val_accuracy: 0.8865 - val_loss: 0.3444
# Epoch 61/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9799 - Precision: 0.9238 - Recall: 0.9238 - accuracy: 0.9238 - loss: 0.1994 - lr: 0.0009023947059176862
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9799 - Precision: 0.9238 - Recall: 0.9238 - accuracy: 0.9238 - loss: 0.1994 - val_AUC: 0.9627 - val_Precision: 0.9004 - val_Recall: 0.9004 - val_accuracy: 0.9004 - val_loss: 0.2968
# Epoch 62/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9750 - Precision: 0.9170 - Recall: 0.9170 - accuracy: 0.9170 - loss: 0.2187 - lr: 0.0008992823422886431
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9750 - Precision: 0.9174 - Recall: 0.9174 - accuracy: 0.9174 - loss: 0.2183 - val_AUC: 0.9606 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.3093
# Epoch 63/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9743 - Precision: 0.9212 - Recall: 0.9212 - accuracy: 0.9212 - loss: 0.2190 - lr: 0.0008961267885752022
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9744 - Precision: 0.9210 - Recall: 0.9210 - accuracy: 0.9210 - loss: 0.2189 - val_AUC: 0.9260 - val_Precision: 0.8805 - val_Recall: 0.8805 - val_accuracy: 0.8805 - val_loss: 0.4522
# Epoch 64/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9777 - Precision: 0.9235 - Recall: 0.9235 - accuracy: 0.9235 - loss: 0.2054 - lr: 0.0008929282776080072
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9776 - Precision: 0.9235 - Recall: 0.9235 - accuracy: 0.9235 - loss: 0.2056 - val_AUC: 0.9639 - val_Precision: 0.9044 - val_Recall: 0.9044 - val_accuracy: 0.9044 - val_loss: 0.3048
# Epoch 65/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9822 - Precision: 0.9278 - Recall: 0.9278 - accuracy: 0.9278 - loss: 0.1954 - lr: 0.0008896872168406844
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9821 - Precision: 0.9276 - Recall: 0.9276 - accuracy: 0.9276 - loss: 0.1958 - val_AUC: 0.9510 - val_Precision: 0.9044 - val_Recall: 0.9044 - val_accuracy: 0.9044 - val_loss: 0.3625
# Epoch 66/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9784 - Precision: 0.9205 - Recall: 0.9205 - accuracy: 0.9205 - loss: 0.2114 - lr: 0.0008864041301421821
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9784 - Precision: 0.9204 - Recall: 0.9204 - accuracy: 0.9204 - loss: 0.2111 - val_AUC: 0.9524 - val_Precision: 0.8944 - val_Recall: 0.8944 - val_accuracy: 0.8944 - val_loss: 0.3840
# Epoch 67/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9780 - Precision: 0.9269 - Recall: 0.9269 - accuracy: 0.9269 - loss: 0.2025 - lr: 0.0008830790757201612
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9780 - Precision: 0.9268 - Recall: 0.9268 - accuracy: 0.9268 - loss: 0.2026 - val_AUC: 0.9529 - val_Precision: 0.9064 - val_Recall: 0.9064 - val_accuracy: 0.9064 - val_loss: 0.3386
# Epoch 68/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9831 - Precision: 0.9335 - Recall: 0.9335 - accuracy: 0.9335 - loss: 0.1929 - lr: 0.0008797125774435699
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9827 - Precision: 0.9330 - Recall: 0.9330 - accuracy: 0.9330 - loss: 0.1939 - val_AUC: 0.9465 - val_Precision: 0.8904 - val_Recall: 0.8904 - val_accuracy: 0.8904 - val_loss: 0.3743
# Epoch 69/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9847 - Precision: 0.9287 - Recall: 0.9287 - accuracy: 0.9287 - loss: 0.1823 - lr: 0.0008763050427660346
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9846 - Precision: 0.9286 - Recall: 0.9286 - accuracy: 0.9286 - loss: 0.1827 - val_AUC: 0.9514 - val_Precision: 0.8984 - val_Recall: 0.8984 - val_accuracy: 0.8984 - val_loss: 0.3399
# Epoch 70/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9811 - Precision: 0.9275 - Recall: 0.9275 - accuracy: 0.9275 - loss: 0.1966 - lr: 0.000872856704518199
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9810 - Precision: 0.9274 - Recall: 0.9274 - accuracy: 0.9274 - loss: 0.1968 - val_AUC: 0.9594 - val_Precision: 0.9143 - val_Recall: 0.9143 - val_accuracy: 0.9143 - val_loss: 0.3152
# Epoch 71/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9821 - Precision: 0.9277 - Recall: 0.9277 - accuracy: 0.9277 - loss: 0.1889 - lr: 0.0008693681447766721
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9820 - Precision: 0.9280 - Recall: 0.9280 - accuracy: 0.9280 - loss: 0.1895 - val_AUC: 0.9539 - val_Precision: 0.9004 - val_Recall: 0.9004 - val_accuracy: 0.9004 - val_loss: 0.3477
# Epoch 72/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9828 - Precision: 0.9356 - Recall: 0.9356 - accuracy: 0.9356 - loss: 0.1854 - lr: 0.0008658395381644368
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9827 - Precision: 0.9354 - Recall: 0.9354 - accuracy: 0.9354 - loss: 0.1858 - val_AUC: 0.9524 - val_Precision: 0.8944 - val_Recall: 0.8944 - val_accuracy: 0.8944 - val_loss: 0.3379
# Epoch 73/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9766 - Precision: 0.9134 - Recall: 0.9134 - accuracy: 0.9134 - loss: 0.2131 - lr: 0.0008622713503427804
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9767 - Precision: 0.9136 - Recall: 0.9136 - accuracy: 0.9136 - loss: 0.2128 - val_AUC: 0.9604 - val_Precision: 0.9064 - val_Recall: 0.9064 - val_accuracy: 0.9064 - val_loss: 0.3127
# Epoch 74/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9757 - Precision: 0.9196 - Recall: 0.9196 - accuracy: 0.9196 - loss: 0.2135 - lr: 0.0008586639887653291
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9758 - Precision: 0.9197 - Recall: 0.9197 - accuracy: 0.9197 - loss: 0.2132 - val_AUC: 0.9658 - val_Precision: 0.9024 - val_Recall: 0.9024 - val_accuracy: 0.9024 - val_loss: 0.2775
# Epoch 75/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9800 - Precision: 0.9186 - Recall: 0.9186 - accuracy: 0.9186 - loss: 0.1969 - lr: 0.0008550179190933704
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9800 - Precision: 0.9187 - Recall: 0.9187 - accuracy: 0.9187 - loss: 0.1970 - val_AUC: 0.9584 - val_Precision: 0.9143 - val_Recall: 0.9143 - val_accuracy: 0.9143 - val_loss: 0.3155
# Epoch 76/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9794 - Precision: 0.9342 - Recall: 0.9342 - accuracy: 0.9342 - loss: 0.1919 - lr: 0.0008513334323652089
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.9794 - Precision: 0.9338 - Recall: 0.9338 - accuracy: 0.9338 - loss: 0.1922 - val_AUC: 0.9660 - val_Precision: 0.9104 - val_Recall: 0.9104 - val_accuracy: 0.9104 - val_loss: 0.2751
# Epoch 77/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9794 - Precision: 0.9237 - Recall: 0.9237 - accuracy: 0.9237 - loss: 0.1985 - lr: 0.0008476109360344708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9794 - Precision: 0.9238 - Recall: 0.9238 - accuracy: 0.9238 - loss: 0.1985 - val_AUC: 0.9558 - val_Precision: 0.9223 - val_Recall: 0.9223 - val_accuracy: 0.9223 - val_loss: 0.3394
# Epoch 78/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9845 - Precision: 0.9344 - Recall: 0.9344 - accuracy: 0.9344 - loss: 0.1835 - lr: 0.0008438508957624435
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9844 - Precision: 0.9342 - Recall: 0.9342 - accuracy: 0.9342 - loss: 0.1837 - val_AUC: 0.9593 - val_Precision: 0.9024 - val_Recall: 0.9024 - val_accuracy: 0.9024 - val_loss: 0.3142
# Epoch 79/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9829 - Precision: 0.9341 - Recall: 0.9341 - accuracy: 0.9341 - loss: 0.1866 - lr: 0.0008400536607950926
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9829 - Precision: 0.9341 - Recall: 0.9341 - accuracy: 0.9341 - loss: 0.1864 - val_AUC: 0.9575 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.3478
# Epoch 80/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9823 - Precision: 0.9349 - Recall: 0.9349 - accuracy: 0.9349 - loss: 0.1827 - lr: 0.0008362196385860443
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9823 - Precision: 0.9348 - Recall: 0.9348 - accuracy: 0.9348 - loss: 0.1830 - val_AUC: 0.9577 - val_Precision: 0.8904 - val_Recall: 0.8904 - val_accuracy: 0.8904 - val_loss: 0.3244
# Epoch 81/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9811 - Precision: 0.9313 - Recall: 0.9313 - accuracy: 0.9313 - loss: 0.1933 - lr: 0.0008323494112119079
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9812 - Precision: 0.9314 - Recall: 0.9314 - accuracy: 0.9314 - loss: 0.1930 - val_AUC: 0.9632 - val_Precision: 0.9303 - val_Recall: 0.9303 - val_accuracy: 0.9303 - val_loss: 0.2921
# Epoch 82/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9837 - Precision: 0.9343 - Recall: 0.9343 - accuracy: 0.9343 - loss: 0.1762 - lr: 0.0008284432115033269
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9834 - Precision: 0.9339 - Recall: 0.9339 - accuracy: 0.9339 - loss: 0.1776 - val_AUC: 0.9658 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.3012
# Epoch 83/300
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9822 - Precision: 0.9278 - Recall: 0.9278 - accuracy: 0.9278 - loss: 0.1896 - lr: 0.0008245016215369105
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9822 - Precision: 0.9283 - Recall: 0.9283 - accuracy: 0.9283 - loss: 0.1893 - val_AUC: 0.9686 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.2826
# Epoch 84/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9801 - Precision: 0.9294 - Recall: 0.9294 - accuracy: 0.9294 - loss: 0.1898 - lr: 0.0008205249323509634
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9802 - Precision: 0.9293 - Recall: 0.9293 - accuracy: 0.9293 - loss: 0.1898 - val_AUC: 0.9604 - val_Precision: 0.9143 - val_Recall: 0.9143 - val_accuracy: 0.9143 - val_loss: 0.3013
# Epoch 85/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9730 - Precision: 0.9202 - Recall: 0.9202 - accuracy: 0.9202 - loss: 0.2138 - lr: 0.0008165136096067727
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.9733 - Precision: 0.9204 - Recall: 0.9204 - accuracy: 0.9204 - loss: 0.2128 - val_AUC: 0.9638 - val_Precision: 0.9064 - val_Recall: 0.9064 - val_accuracy: 0.9064 - val_loss: 0.3016
# Epoch 86/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9811 - Precision: 0.9273 - Recall: 0.9273 - accuracy: 0.9273 - loss: 0.1924 - lr: 0.0008124682353809476
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9811 - Precision: 0.9275 - Recall: 0.9275 - accuracy: 0.9275 - loss: 0.1923 - val_AUC: 0.9572 - val_Precision: 0.9084 - val_Recall: 0.9084 - val_accuracy: 0.9084 - val_loss: 0.3208
# Epoch 87/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9863 - Precision: 0.9432 - Recall: 0.9432 - accuracy: 0.9432 - loss: 0.1686 - lr: 0.0008083890425041318
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9861 - Precision: 0.9426 - Recall: 0.9426 - accuracy: 0.9426 - loss: 0.1695 - val_AUC: 0.9589 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.3237
# Epoch 88/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9876 - Precision: 0.9440 - Recall: 0.9440 - accuracy: 0.9440 - loss: 0.1638 - lr: 0.0008042766130529344
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9875 - Precision: 0.9439 - Recall: 0.9439 - accuracy: 0.9439 - loss: 0.1640 - val_AUC: 0.9612 - val_Precision: 0.9243 - val_Recall: 0.9243 - val_accuracy: 0.9243 - val_loss: 0.3054
# Epoch 89/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9817 - Precision: 0.9421 - Recall: 0.9421 - accuracy: 0.9421 - loss: 0.1856 - lr: 0.0008001312962733209
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9817 - Precision: 0.9420 - Recall: 0.9420 - accuracy: 0.9420 - loss: 0.1855 - val_AUC: 0.9638 - val_Precision: 0.9163 - val_Recall: 0.9163 - val_accuracy: 0.9163 - val_loss: 0.2861
# Epoch 90/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9867 - Precision: 0.9339 - Recall: 0.9339 - accuracy: 0.9339 - loss: 0.1737 - lr: 0.0007959537324495614
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9865 - Precision: 0.9344 - Recall: 0.9344 - accuracy: 0.9344 - loss: 0.1742 - val_AUC: 0.9570 - val_Precision: 0.9223 - val_Recall: 0.9223 - val_accuracy: 0.9223 - val_loss: 0.3566
# Epoch 91/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9854 - Precision: 0.9347 - Recall: 0.9347 - accuracy: 0.9347 - loss: 0.1745 - lr: 0.0007917441544122994
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9854 - Precision: 0.9346 - Recall: 0.9346 - accuracy: 0.9346 - loss: 0.1747 - val_AUC: 0.9651 - val_Precision: 0.9143 - val_Recall: 0.9143 - val_accuracy: 0.9143 - val_loss: 0.2819
# Epoch 92/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9849 - Precision: 0.9429 - Recall: 0.9429 - accuracy: 0.9429 - loss: 0.1693 - lr: 0.0007875032024458051
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9849 - Precision: 0.9428 - Recall: 0.9428 - accuracy: 0.9428 - loss: 0.1694 - val_AUC: 0.9582 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.3376
# Epoch 93/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9815 - Precision: 0.9254 - Recall: 0.9254 - accuracy: 0.9254 - loss: 0.1879 - lr: 0.0007832312840037048
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9814 - Precision: 0.9258 - Recall: 0.9258 - accuracy: 0.9258 - loss: 0.1880 - val_AUC: 0.9625 - val_Precision: 0.9283 - val_Recall: 0.9283 - val_accuracy: 0.9283 - val_loss: 0.3036
# Epoch 94/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9805 - Precision: 0.9319 - Recall: 0.9319 - accuracy: 0.9319 - loss: 0.1898 - lr: 0.0007789288647472858
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9805 - Precision: 0.9319 - Recall: 0.9319 - accuracy: 0.9319 - loss: 0.1897 - val_AUC: 0.9633 - val_Precision: 0.9243 - val_Recall: 0.9243 - val_accuracy: 0.9243 - val_loss: 0.2788
# Epoch 95/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9860 - Precision: 0.9481 - Recall: 0.9481 - accuracy: 0.9481 - loss: 0.1691 - lr: 0.0007745962939225137
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9859 - Precision: 0.9475 - Recall: 0.9475 - accuracy: 0.9475 - loss: 0.1695 - val_AUC: 0.9589 - val_Precision: 0.9024 - val_Recall: 0.9024 - val_accuracy: 0.9024 - val_loss: 0.3292
# Epoch 96/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9852 - Precision: 0.9383 - Recall: 0.9383 - accuracy: 0.9383 - loss: 0.1754 - lr: 0.0007702342700213194
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9852 - Precision: 0.9384 - Recall: 0.9384 - accuracy: 0.9384 - loss: 0.1754 - val_AUC: 0.9583 - val_Precision: 0.8984 - val_Recall: 0.8984 - val_accuracy: 0.8984 - val_loss: 0.3114
# Epoch 97/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9838 - Precision: 0.9324 - Recall: 0.9324 - accuracy: 0.9324 - loss: 0.1789 - lr: 0.0007658432004973292
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9837 - Precision: 0.9325 - Recall: 0.9325 - accuracy: 0.9325 - loss: 0.1791 - val_AUC: 0.9660 - val_Precision: 0.9064 - val_Recall: 0.9064 - val_accuracy: 0.9064 - val_loss: 0.2867
# Epoch 98/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9854 - Precision: 0.9364 - Recall: 0.9364 - accuracy: 0.9364 - loss: 0.1780 - lr: 0.0007614234345965087
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9854 - Precision: 0.9365 - Recall: 0.9365 - accuracy: 0.9365 - loss: 0.1778 - val_AUC: 0.9582 - val_Precision: 0.9044 - val_Recall: 0.9044 - val_accuracy: 0.9044 - val_loss: 0.3257
# Epoch 99/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9873 - Precision: 0.9408 - Recall: 0.9408 - accuracy: 0.9408 - loss: 0.1679 - lr: 0.0007569754961878061
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9873 - Precision: 0.9409 - Recall: 0.9409 - accuracy: 0.9409 - loss: 0.1680 - val_AUC: 0.9673 - val_Precision: 0.9223 - val_Recall: 0.9223 - val_accuracy: 0.9223 - val_loss: 0.2947
# Epoch 100/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9832 - Precision: 0.9331 - Recall: 0.9331 - accuracy: 0.9331 - loss: 0.1746 - lr: 0.0007525000255554914
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9833 - Precision: 0.9333 - Recall: 0.9333 - accuracy: 0.9333 - loss: 0.1743 - val_AUC: 0.9507 - val_Precision: 0.9104 - val_Recall: 0.9104 - val_accuracy: 0.9104 - val_loss: 0.3413
# Epoch 101/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9851 - Precision: 0.9392 - Recall: 0.9392 - accuracy: 0.9392 - loss: 0.1685 - lr: 0.0007479973719455302
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9852 - Precision: 0.9390 - Recall: 0.9390 - accuracy: 0.9390 - loss: 0.1685 - val_AUC: 0.9556 - val_Precision: 0.9104 - val_Recall: 0.9104 - val_accuracy: 0.9104 - val_loss: 0.3277
# Epoch 102/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9827 - Precision: 0.9310 - Recall: 0.9310 - accuracy: 0.9310 - loss: 0.1751 - lr: 0.0007434680592268705
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9828 - Precision: 0.9312 - Recall: 0.9312 - accuracy: 0.9312 - loss: 0.1752 - val_AUC: 0.9665 - val_Precision: 0.9044 - val_Recall: 0.9044 - val_accuracy: 0.9044 - val_loss: 0.2800
# Epoch 103/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9835 - Precision: 0.9294 - Recall: 0.9294 - accuracy: 0.9294 - loss: 0.1821 - lr: 0.0007389126694761217
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9837 - Precision: 0.9304 - Recall: 0.9304 - accuracy: 0.9304 - loss: 0.1806 - val_AUC: 0.9640 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.2897
# Epoch 104/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9864 - Precision: 0.9429 - Recall: 0.9429 - accuracy: 0.9429 - loss: 0.1689 - lr: 0.00073433161014691
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9863 - Precision: 0.9426 - Recall: 0.9426 - accuracy: 0.9426 - loss: 0.1691 - val_AUC: 0.9573 - val_Precision: 0.9203 - val_Recall: 0.9203 - val_accuracy: 0.9203 - val_loss: 0.3368
# Epoch 105/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9848 - Precision: 0.9405 - Recall: 0.9405 - accuracy: 0.9405 - loss: 0.1732 - lr: 0.0007297253469005227
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9847 - Precision: 0.9401 - Recall: 0.9401 - accuracy: 0.9401 - loss: 0.1737 - val_AUC: 0.9578 - val_Precision: 0.9223 - val_Recall: 0.9223 - val_accuracy: 0.9223 - val_loss: 0.3455
# Epoch 106/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9893 - Precision: 0.9459 - Recall: 0.9459 - accuracy: 0.9459 - loss: 0.1507 - lr: 0.0007250944036059082
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9891 - Precision: 0.9457 - Recall: 0.9457 - accuracy: 0.9457 - loss: 0.1514 - val_AUC: 0.9548 - val_Precision: 0.9104 - val_Recall: 0.9104 - val_accuracy: 0.9104 - val_loss: 0.3723
# Epoch 107/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9848 - Precision: 0.9277 - Recall: 0.9277 - accuracy: 0.9277 - loss: 0.1731 - lr: 0.0007204394205473363
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9848 - Precision: 0.9282 - Recall: 0.9282 - accuracy: 0.9282 - loss: 0.1733 - val_AUC: 0.9686 - val_Precision: 0.9283 - val_Recall: 0.9283 - val_accuracy: 0.9283 - val_loss: 0.2836
# Epoch 108/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9882 - Precision: 0.9408 - Recall: 0.9408 - accuracy: 0.9408 - loss: 0.1622 - lr: 0.0007157607469707727
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9881 - Precision: 0.9407 - Recall: 0.9407 - accuracy: 0.9407 - loss: 0.1625 - val_AUC: 0.9586 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.3221
# Epoch 109/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9874 - Precision: 0.9441 - Recall: 0.9441 - accuracy: 0.9441 - loss: 0.1631 - lr: 0.0007110590231604874
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9874 - Precision: 0.9440 - Recall: 0.9440 - accuracy: 0.9440 - loss: 0.1634 - val_AUC: 0.9629 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.2864
# Epoch 110/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9875 - Precision: 0.9431 - Recall: 0.9431 - accuracy: 0.9431 - loss: 0.1600 - lr: 0.0007063345983624458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9876 - Precision: 0.9433 - Recall: 0.9433 - accuracy: 0.9433 - loss: 0.1598 - val_AUC: 0.9694 - val_Precision: 0.9283 - val_Recall: 0.9283 - val_accuracy: 0.9283 - val_loss: 0.2752
# Epoch 111/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9858 - Precision: 0.9444 - Recall: 0.9444 - accuracy: 0.9444 - loss: 0.1666 - lr: 0.0007015882292762399
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9856 - Precision: 0.9440 - Recall: 0.9440 - accuracy: 0.9440 - loss: 0.1672 - val_AUC: 0.9549 - val_Precision: 0.9084 - val_Recall: 0.9084 - val_accuracy: 0.9084 - val_loss: 0.3685
# Epoch 112/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9843 - Precision: 0.9278 - Recall: 0.9278 - accuracy: 0.9278 - loss: 0.1734 - lr: 0.0006968202069401741
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9845 - Precision: 0.9286 - Recall: 0.9286 - accuracy: 0.9286 - loss: 0.1726 - val_AUC: 0.9678 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2842
# Epoch 113/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9859 - Precision: 0.9346 - Recall: 0.9346 - accuracy: 0.9346 - loss: 0.1692 - lr: 0.0006920311716385186
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9859 - Precision: 0.9347 - Recall: 0.9347 - accuracy: 0.9347 - loss: 0.1691 - val_AUC: 0.9624 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.2812
# Epoch 114/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9889 - Precision: 0.9432 - Recall: 0.9432 - accuracy: 0.9432 - loss: 0.1530 - lr: 0.0006872217054478824
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9888 - Precision: 0.9434 - Recall: 0.9434 - accuracy: 0.9434 - loss: 0.1532 - val_AUC: 0.9624 - val_Precision: 0.9303 - val_Recall: 0.9303 - val_accuracy: 0.9303 - val_loss: 0.3042
# Epoch 115/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9886 - Precision: 0.9478 - Recall: 0.9478 - accuracy: 0.9478 - loss: 0.1580 - lr: 0.0006823921576142311
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9885 - Precision: 0.9475 - Recall: 0.9475 - accuracy: 0.9475 - loss: 0.1582 - val_AUC: 0.9614 - val_Precision: 0.9203 - val_Recall: 0.9203 - val_accuracy: 0.9203 - val_loss: 0.3044
# Epoch 116/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9877 - Precision: 0.9523 - Recall: 0.9523 - accuracy: 0.9523 - loss: 0.1536 - lr: 0.0006775431684218347
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9877 - Precision: 0.9519 - Recall: 0.9519 - accuracy: 0.9519 - loss: 0.1540 - val_AUC: 0.9607 - val_Precision: 0.9124 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_loss: 0.3030
# Epoch 117/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9868 - Precision: 0.9441 - Recall: 0.9441 - accuracy: 0.9441 - loss: 0.1587 - lr: 0.0006726753199473023
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9868 - Precision: 0.9439 - Recall: 0.9439 - accuracy: 0.9439 - loss: 0.1592 - val_AUC: 0.9706 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2443
# Epoch 118/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9893 - Precision: 0.9489 - Recall: 0.9489 - accuracy: 0.9489 - loss: 0.1528 - lr: 0.0006677889614365995
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9892 - Precision: 0.9485 - Recall: 0.9485 - accuracy: 0.9485 - loss: 0.1531 - val_AUC: 0.9679 - val_Precision: 0.9163 - val_Recall: 0.9163 - val_accuracy: 0.9163 - val_loss: 0.2705
# Epoch 119/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9866 - Precision: 0.9332 - Recall: 0.9332 - accuracy: 0.9332 - loss: 0.1671 - lr: 0.000662884849589318
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9866 - Precision: 0.9333 - Recall: 0.9333 - accuracy: 0.9333 - loss: 0.1671 - val_AUC: 0.9658 - val_Precision: 0.9283 - val_Recall: 0.9283 - val_accuracy: 0.9283 - val_loss: 0.2880
# Epoch 120/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9887 - Precision: 0.9457 - Recall: 0.9457 - accuracy: 0.9457 - loss: 0.1543 - lr: 0.0006579634500667453
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9887 - Precision: 0.9456 - Recall: 0.9456 - accuracy: 0.9456 - loss: 0.1545 - val_AUC: 0.9588 - val_Precision: 0.9243 - val_Recall: 0.9243 - val_accuracy: 0.9243 - val_loss: 0.3428
# Epoch 121/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9896 - Precision: 0.9504 - Recall: 0.9504 - accuracy: 0.9504 - loss: 0.1539 - lr: 0.0006530252285301685
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9895 - Precision: 0.9501 - Recall: 0.9501 - accuracy: 0.9501 - loss: 0.1543 - val_AUC: 0.9622 - val_Precision: 0.9183 - val_Recall: 0.9183 - val_accuracy: 0.9183 - val_loss: 0.2994
# Epoch 122/300
# ...
# Epoch 261/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - AUC: 0.9919 - Precision: 0.9616 - Recall: 0.9616 - accuracy: 0.9616 - loss: 0.1253 - lr: 5.0711416406556964e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.9919 - Precision: 0.9617 - Recall: 0.9617 - accuracy: 0.9617 - loss: 0.1252 - val_AUC: 0.9695 - val_Precision: 0.9303 - val_Recall: 0.9303 - val_accuracy: 0.9303 - val_loss: 0.2737
# Epoch 262/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - AUC: 0.9958 - Precision: 0.9662 - Recall: 0.9662 - accuracy: 0.9662 - loss: 0.1064 - lr: 4.867775351158343e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.9957 - Precision: 0.9659 - Recall: 0.9659 - accuracy: 0.9659 - loss: 0.1069 - val_AUC: 0.9697 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2691
# Epoch 263/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - AUC: 0.9933 - Precision: 0.9670 - Recall: 0.9670 - accuracy: 0.9670 - loss: 0.1151 - lr: 4.6694058255525306e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.9932 - Precision: 0.9666 - Recall: 0.9666 - accuracy: 0.9666 - loss: 0.1157 - val_AUC: 0.9712 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2727
# Epoch 264/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9911 - Precision: 0.9552 - Recall: 0.9552 - accuracy: 0.9552 - loss: 0.1267 - lr: 4.476061076275073e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.9911 - Precision: 0.9554 - Recall: 0.9554 - accuracy: 0.9554 - loss: 0.1266 - val_AUC: 0.9696 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2738
# Epoch 265/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.9915 - Precision: 0.9543 - Recall: 0.9543 - accuracy: 0.9543 - loss: 0.1267 - lr: 4.287767660571262e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.9916 - Precision: 0.9547 - Recall: 0.9547 - accuracy: 0.9547 - loss: 0.1265 - val_AUC: 0.9732 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2654
# Epoch 266/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9950 - Precision: 0.9642 - Recall: 0.9642 - accuracy: 0.9642 - loss: 0.1141 - lr: 4.104539766558446e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9950 - Precision: 0.9640 - Recall: 0.9640 - accuracy: 0.9640 - loss: 0.1142 - val_AUC: 0.9729 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2690
# Epoch 267/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9950 - Precision: 0.9676 - Recall: 0.9676 - accuracy: 0.9676 - loss: 0.1124 - lr: 3.926401768694632e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9949 - Precision: 0.9675 - Recall: 0.9675 - accuracy: 0.9675 - loss: 0.1125 - val_AUC: 0.9728 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2721
# Epoch 268/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9932 - Precision: 0.9593 - Recall: 0.9593 - accuracy: 0.9593 - loss: 0.1206 - lr: 3.753367855097167e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9932 - Precision: 0.9593 - Recall: 0.9593 - accuracy: 0.9593 - loss: 0.1205 - val_AUC: 0.9713 - val_Precision: 0.9303 - val_Recall: 0.9303 - val_accuracy: 0.9303 - val_loss: 0.2711
# Epoch 269/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9943 - Precision: 0.9681 - Recall: 0.9681 - accuracy: 0.9681 - loss: 0.1102 - lr: 3.5854616726282984e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9942 - Precision: 0.9678 - Recall: 0.9678 - accuracy: 0.9678 - loss: 0.1108 - val_AUC: 0.9729 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2664
# Epoch 270/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9948 - Precision: 0.9634 - Recall: 0.9634 - accuracy: 0.9634 - loss: 0.1095 - lr: 3.4227043215651065e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9948 - Precision: 0.9635 - Recall: 0.9635 - accuracy: 0.9635 - loss: 0.1095 - val_AUC: 0.9728 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2670
# Epoch 271/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9964 - Precision: 0.9667 - Recall: 0.9667 - accuracy: 0.9667 - loss: 0.1060 - lr: 3.265104169258848e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9963 - Precision: 0.9663 - Recall: 0.9663 - accuracy: 0.9663 - loss: 0.1069 - val_AUC: 0.9713 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2649
# Epoch 272/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9935 - Precision: 0.9625 - Recall: 0.9625 - accuracy: 0.9625 - loss: 0.1192 - lr: 3.112681952188723e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.9935 - Precision: 0.9626 - Recall: 0.9626 - accuracy: 0.9626 - loss: 0.1193 - val_AUC: 0.9714 - val_Precision: 0.9343 - val_Recall: 0.9343 - val_accuracy: 0.9343 - val_loss: 0.2667
# Epoch 273/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.9937 - Precision: 0.9580 - Recall: 0.9580 - accuracy: 0.9580 - loss: 0.1227 - lr: 2.965458588732872e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.9938 - Precision: 0.9586 - Recall: 0.9586 - accuracy: 0.9586 - loss: 0.1219 - val_AUC: 0.9731 - val_Precision: 0.9343 - val_Recall: 0.9343 - val_accuracy: 0.9343 - val_loss: 0.2681
# Epoch 274/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9925 - Precision: 0.9532 - Recall: 0.9532 - accuracy: 0.9532 - loss: 0.1264 - lr: 2.8234513592906296e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9925 - Precision: 0.9534 - Recall: 0.9534 - accuracy: 0.9534 - loss: 0.1265 - val_AUC: 0.9733 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2663
# Epoch 275/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9957 - Precision: 0.9632 - Recall: 0.9632 - accuracy: 0.9632 - loss: 0.1113 - lr: 2.686669358809013e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9957 - Precision: 0.9631 - Recall: 0.9631 - accuracy: 0.9631 - loss: 0.1118 - val_AUC: 0.9733 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2647
# Epoch 276/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9954 - Precision: 0.9658 - Recall: 0.9658 - accuracy: 0.9658 - loss: 0.1119 - lr: 2.555130595283117e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9954 - Precision: 0.9654 - Recall: 0.9654 - accuracy: 0.9654 - loss: 0.1121 - val_AUC: 0.9732 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2624
# Epoch 277/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9944 - Precision: 0.9658 - Recall: 0.9658 - accuracy: 0.9658 - loss: 0.1127 - lr: 2.4288521672133356e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9944 - Precision: 0.9658 - Recall: 0.9658 - accuracy: 0.9658 - loss: 0.1128 - val_AUC: 0.9730 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2650
# Epoch 278/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9936 - Precision: 0.9658 - Recall: 0.9658 - accuracy: 0.9658 - loss: 0.1136 - lr: 2.307843169546686e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9936 - Precision: 0.9657 - Recall: 0.9657 - accuracy: 0.9657 - loss: 0.1139 - val_AUC: 0.9714 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2667
# Epoch 279/300
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9928 - Precision: 0.9561 - Recall: 0.9561 - accuracy: 0.9561 - loss: 0.1213 - lr: 2.192121246480383e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9929 - Precision: 0.9567 - Recall: 0.9567 - accuracy: 0.9567 - loss: 0.1208 - val_AUC: 0.9717 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2609
# Epoch 280/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9921 - Precision: 0.9583 - Recall: 0.9583 - accuracy: 0.9583 - loss: 0.1249 - lr: 2.0816927644773386e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9921 - Precision: 0.9584 - Recall: 0.9584 - accuracy: 0.9584 - loss: 0.1246 - val_AUC: 0.9718 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2603
# Epoch 281/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9955 - Precision: 0.9700 - Recall: 0.9700 - accuracy: 0.9700 - loss: 0.1104 - lr: 1.976574640139006e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9955 - Precision: 0.9699 - Recall: 0.9699 - accuracy: 0.9699 - loss: 0.1106 - val_AUC: 0.9716 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2643
# Epoch 282/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9927 - Precision: 0.9527 - Recall: 0.9527 - accuracy: 0.9527 - loss: 0.1234 - lr: 1.8767823348753154e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9927 - Precision: 0.9528 - Recall: 0.9528 - accuracy: 0.9528 - loss: 0.1233 - val_AUC: 0.9731 - val_Precision: 0.9343 - val_Recall: 0.9343 - val_accuracy: 0.9343 - val_loss: 0.2634
# Epoch 283/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9949 - Precision: 0.9606 - Recall: 0.9606 - accuracy: 0.9606 - loss: 0.1106 - lr: 1.7823153029894456e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9949 - Precision: 0.9606 - Recall: 0.9606 - accuracy: 0.9606 - loss: 0.1108 - val_AUC: 0.9750 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2630
# Epoch 284/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9940 - Precision: 0.9595 - Recall: 0.9595 - accuracy: 0.9595 - loss: 0.1196 - lr: 1.6931975551415235e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9940 - Precision: 0.9596 - Recall: 0.9596 - accuracy: 0.9596 - loss: 0.1194 - val_AUC: 0.9732 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2636
# Epoch 285/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9956 - Precision: 0.9681 - Recall: 0.9681 - accuracy: 0.9681 - loss: 0.1109 - lr: 1.609425999049563e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9956 - Precision: 0.9678 - Recall: 0.9678 - accuracy: 0.9678 - loss: 0.1114 - val_AUC: 0.9733 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2648
# Epoch 286/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9926 - Precision: 0.9575 - Recall: 0.9575 - accuracy: 0.9575 - loss: 0.1240 - lr: 1.5310184608097188e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9927 - Precision: 0.9576 - Recall: 0.9576 - accuracy: 0.9576 - loss: 0.1237 - val_AUC: 0.9733 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2645
# Epoch 287/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9932 - Precision: 0.9697 - Recall: 0.9697 - accuracy: 0.9697 - loss: 0.1118 - lr: 1.4579834896721877e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9932 - Precision: 0.9695 - Recall: 0.9695 - accuracy: 0.9695 - loss: 0.1121 - val_AUC: 0.9732 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2642
# Epoch 288/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9945 - Precision: 0.9651 - Recall: 0.9651 - accuracy: 0.9651 - loss: 0.1106 - lr: 1.39032126753591e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9945 - Precision: 0.9651 - Recall: 0.9651 - accuracy: 0.9651 - loss: 0.1107 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2645
# Epoch 289/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9967 - Precision: 0.9683 - Recall: 0.9683 - accuracy: 0.9683 - loss: 0.1042 - lr: 1.3280465282150544e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.9966 - Precision: 0.9680 - Recall: 0.9680 - accuracy: 0.9680 - loss: 0.1047 - val_AUC: 0.9731 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2645
# Epoch 290/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9917 - Precision: 0.9621 - Recall: 0.9621 - accuracy: 0.9621 - loss: 0.1171 - lr: 1.2711651834251825e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9917 - Precision: 0.9620 - Recall: 0.9620 - accuracy: 0.9620 - loss: 0.1173 - val_AUC: 0.9716 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2650
# Epoch 291/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9945 - Precision: 0.9592 - Recall: 0.9592 - accuracy: 0.9592 - loss: 0.1176 - lr: 1.21968023449881e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9943 - Precision: 0.9593 - Recall: 0.9593 - accuracy: 0.9593 - loss: 0.1179 - val_AUC: 0.9697 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2666
# Epoch 292/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9944 - Precision: 0.9565 - Recall: 0.9565 - accuracy: 0.9565 - loss: 0.1189 - lr: 1.1736033229681198e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9943 - Precision: 0.9566 - Recall: 0.9566 - accuracy: 0.9566 - loss: 0.1189 - val_AUC: 0.9713 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2655
# Epoch 293/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9927 - Precision: 0.9675 - Recall: 0.9675 - accuracy: 0.9675 - loss: 0.1171 - lr: 1.1329316293995362e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9927 - Precision: 0.9673 - Recall: 0.9673 - accuracy: 0.9673 - loss: 0.1172 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2658
# Epoch 294/300
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9942 - Precision: 0.9612 - Recall: 0.9612 - accuracy: 0.9612 - loss: 0.1184 - lr: 1.0976769772241823e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9943 - Precision: 0.9614 - Recall: 0.9614 - accuracy: 0.9614 - loss: 0.1181 - val_AUC: 0.9714 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2663
# Epoch 295/300
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9959 - Precision: 0.9602 - Recall: 0.9602 - accuracy: 0.9602 - loss: 0.1104 - lr: 1.0678363651095424e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9958 - Precision: 0.9599 - Recall: 0.9599 - accuracy: 0.9599 - loss: 0.1107 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2662
# Epoch 296/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9958 - Precision: 0.9677 - Recall: 0.9677 - accuracy: 0.9677 - loss: 0.1101 - lr: 1.0434185242047533e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9957 - Precision: 0.9675 - Recall: 0.9675 - accuracy: 0.9675 - loss: 0.1104 - val_AUC: 0.9714 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2669
# Epoch 297/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9897 - Precision: 0.9541 - Recall: 0.9541 - accuracy: 0.9541 - loss: 0.1310 - lr: 1.0244266377412714e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9898 - Precision: 0.9542 - Recall: 0.9542 - accuracy: 0.9542 - loss: 0.1308 - val_AUC: 0.9714 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2655
# Epoch 298/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.9944 - Precision: 0.9645 - Recall: 0.9645 - accuracy: 0.9645 - loss: 0.1122 - lr: 1.0108547030540649e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9943 - Precision: 0.9645 - Recall: 0.9645 - accuracy: 0.9645 - loss: 0.1122 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2650
# Epoch 299/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9954 - Precision: 0.9677 - Recall: 0.9677 - accuracy: 0.9677 - loss: 0.1057 - lr: 1.0027144526247866e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.9953 - Precision: 0.9676 - Recall: 0.9676 - accuracy: 0.9676 - loss: 0.1061 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2661
# Epoch 300/300
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.9953 - Precision: 0.9665 - Recall: 0.9665 - accuracy: 0.9665 - loss: 0.1107 - lr: 1.0000000656873453e-05
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9952 - Precision: 0.9663 - Recall: 0.9663 - accuracy: 0.9663 - loss: 0.1110 - val_AUC: 0.9715 - val_Precision: 0.9323 - val_Recall: 0.9323 - val_accuracy: 0.9323 - val_loss: 0.2666

# %%
fig, axs = plt.subplots(1,2, figsize=(12, 4))
    
# Subplot 1: Plot training & validation accuracy values
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy ' + model_name)

axs[0].axhline(y=max(history.history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(0,0.93, f'Max Acc: {max(history.history["accuracy"])}', color='b')  # Add text annotation with the max value

axs[0].axhline(y=max(history.history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(0,0.83, f'Max Val Acc: {max(history.history["val_accuracy"])}', color='red')  # Add text annotation with the max value
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend(['Train', 'Val'], loc='upper left')
axs[0].set_ylim(0.5, 1)

# Subplot 2: Plot training & validation loss values
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss ' + model_name)
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['Train', 'Val'], loc='upper left')
axs[1].set_ylim(0, 1)

axs[1].axhline(y=min(history.history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(0,0.45, f'Min Val loss: {min(history.history["val_loss"])}', color='red')  # Add text annotation with the max value

axs[1].axhline(y=min(history.history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(0,0.1, f'Min loss: {min(history.history["loss"])}', color='b')  # Add text annotation with the max value

# Save the figure with subplots
plt.savefig(f'{plot_folder}\\ACC_LOSS_{model_name}.png')

# Show the plot
plt.show()

# %%
#import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical

# Assuming y_val is one-hot encoded, convert it back to class labels
y_true_classes = np.argmax(y_valEMG, axis=1)

# Make predictions on the validation set
y_pred = model.predict([X_valEMG, X_valContext])

# Convert predictions from sigmoid output to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
cmap = plt.cm.Blues
plt.imshow(cm, interpolation='nearest', cmap=cmap)
plt.title('Confusion Matrix ' + model_name)
plt.colorbar()
tick_marks = np.arange(len(np.unique(y_true_classes)))  # this adapts to the number of classes dynamically
plt.xticks(tick_marks, tick_marks)
plt.yticks(tick_marks, tick_marks)

# Labeling the axes
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations inside the squares
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.savefig(f'{plot_folder}\\CM_{model_name}.png')

plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
mm.save_model(model, model_folder, model_name)
# Out:
# Model saved to .\MODELS_TC\BASE_TASK_CONTEXT_MODEL_6_no_shape.keras

# %%
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
print(f"Training time: {training_time/60} minutes")
# Convert the history object to a dictionary
history_dict = history.history

# Add the training time to the dictionary
history_dict['training_time'] = training_time
history_dict['model'] = model_name
history_dict['batch_size'] = batch_size
history_dict['epochs'] = epochs
history_dict['learning_rate'] = initial_learning_rate
history_dict['decay_steps'] = decay_steps
history_dict['alpha'] = alpha
history_dict['loss_function'] = 'binary_crossentropy'
history_dict['optimizer'] = 'Adam'

# Save the dictionary to a JSON file

mm.save_history(history_dict, model_folder, model_name)
# Out:
# Training time: 207.3325481414795 seconds
# Training time: 3.455542469024658 minutes
# History saved to .\MODELS_TC\BASE_TASK_CONTEXT_MODEL_6_no_shape_history.json

# %%
print('output shape')
print(y_pred.shape)
print('output')
print(y_pred)
# Out:
# output shape
# (502, 2)
# output
# [[7.6968053e-07 9.9999928e-01]
#  [1.0791644e-05 9.9998915e-01]
#  [6.3915073e-09 1.0000000e+00]
#  ...
#  [1.0000000e+00 1.0540864e-13]
#  [1.0000000e+00 3.5497506e-13]
#  [9.9982208e-01 1.7793168e-04]]
