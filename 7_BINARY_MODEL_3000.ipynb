# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, MaxPooling1D, GlobalAveragePooling1D, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import compute_class_weight
from sklearn.utils import class_weight
from tensorflow.keras.metrics import Precision, Recall, AUC, SparseCategoricalAccuracy
import time


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import movmus as mm
import movmus2 as mm2

import json

# %% [markdown]
# ## LOADING DATA

# %%
train_data, val_data, test_data = mm.load_data_npz('EMG_3000_data.npz')
# Out:
# shape of training data: (2720, 3000, 7)
# shape of validation data: (502, 3000, 7)
# shape of test data: (661, 3000, 7)

# %%
train_labels = mm.load_labels('training_labels.npz')
val_labels = mm.load_labels('validation_labels.npz')
test_labels = mm.load_labels('test_labels.npz')
print('train labels:', train_labels.shape, 'val labels:', val_labels.shape, 'test labels:', test_labels.shape)
# Out:
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
train_labels.head()
# Out:
#     ID  GRASP_DH
# 0  1.0       1.0
# 1  2.0       1.0
# 2  3.0       1.0
# 3  4.0       1.0
# 4  5.0       1.0

# %%
train_labels_categorical = mm.adjust_labels(train_labels)
val_labels_categorical = mm.adjust_labels(val_labels)
test_labels_categorical = mm.adjust_labels(test_labels)
print('train labels:', train_labels_categorical.shape, 'val labels:', val_labels_categorical.shape, 'test labels:', test_labels_categorical.shape)
# Out:
# Labels after one-hot encoding: (2720, 2)
# Labels after one-hot encoding: (502, 2)
# Labels after one-hot encoding: (661, 2)
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
print(train_labels_categorical)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
first_column = train_labels_categorical[:, 0]
#print(first_column)
second_column = train_labels_categorical[:, 1]
# Count the number of 0s
count_first = np.count_nonzero(first_column == 1)

# Calculate the percentage
percentage_first = (count_first / len(first_column)) * 100

print(f"Percentage of 1s in the first column: {percentage_first}%")

count_second = np.count_nonzero(second_column == 1)
percentage_second = (count_second / len(second_column)) * 100
print(f"Percentage of 1s in the second column: {percentage_second}%")
# Out:
# Percentage of 1s in the first column: 61.360294117647065%
# Percentage of 1s in the second column: 38.63970588235294%

# %% [markdown]
# ## MODEL CREATION

# %%
from tensorflow.keras.regularizers import l2

# %%
model_name = 'M_20_1_3000'
model_folder = '.\\MODELS_3000'
plot_folder = '.\\PLOTS_3000'

# %%
num_samples = len(train_data)  # Number of training samples
print("Number of training samples:", num_samples)
possible_batch_sizes = [i for i in range(1, num_samples + 1) if num_samples % i == 0]

print("Possible batch sizes that divide evenly:", possible_batch_sizes)
# Out:
# Number of training samples: 2720
# Possible batch sizes that divide evenly: [1, 2, 4, 5, 8, 10, 16, 17, 20, 32, 34, 40, 68, 80, 85, 136, 160, 170, 272, 340, 544, 680, 1360, 2720]

# %%
batch_size = 40
epochs = 300

# %%
# Define the learning rate schedule
initial_learning_rate = 0.001
decay_steps = (num_samples/batch_size)*epochs  # 2752 samples/ 86 bs = 32 --> 32 * 250 epochs = 8000 steps
print("Decay steps:", decay_steps)
alpha = 0.01 

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    alpha=alpha
)
# Out:
# Decay steps: 20400.0

# %%
from tensorflow.keras.callbacks import Callback

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = tf.keras.backend.get_value(self.model.optimizer.learning_rate)
        print(f" - lr: {lr}")

# %%
model = Sequential([
    # Layer 1
    tf.keras.layers.Conv1D(filters=16, kernel_size=5, padding='valid', activation='relu', input_shape=(3000, 7)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    # Layer 2
    tf.keras.layers.Conv1D(filters=32, kernel_size=5, padding='valid', activation='relu'),
    BatchNormalization(),
    GlobalAveragePooling1D(),
    Dropout(0.2),

    # Layer 3
    #tf.keras.layers.Dense(64, activation='relu'),
    #BatchNormalization(),
        
    # Layer 4
    tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=l2(0.02)),

    # Exit layer
    tf.keras.layers.Dense(2, activation='softmax')
])
# Out:
# c:\Users\al385931\AppData\Local\anaconda3\envs\tfm2\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=lr_schedule),
    metrics=['accuracy', Precision(), Recall()] 
)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_8 (Conv1D)               │ (None, 2996, 16)       │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 2996, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 1498, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 1494, 32)       │         2,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 1494, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,482 (17.51 KB)
#  Trainable params: 4,386 (17.13 KB)
#  Non-trainable params: 96 (384.00 B)

# %% [markdown]
# ## TRAINING

# %%
tf.keras.config.disable_traceback_filtering()

# %%
start_time = time.time()

# Train the model
history = model.fit(
    train_data, train_labels_categorical,
    validation_data=(val_data, val_labels_categorical),
    epochs=epochs,  
    batch_size=batch_size,
    callbacks=[LearningRateLogger()],  
    verbose=1)
    #class_weight = class_weight_dict
#)

end_time = time.time()
# Out:
# Epoch 1/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6441 - loss: 1.2284 - precision_4: 0.6441 - recall_4: 0.6441 - lr: 0.0009999729227274656
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.6453 - loss: 1.2265 - precision_4: 0.6453 - recall_4: 0.6453 - val_accuracy: 0.5339 - val_loss: 1.0900 - val_precision_4: 0.5339 - val_recall_4: 0.5339
# Epoch 2/300
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7944 - loss: 0.8398 - precision_4: 0.7944 - recall_4: 0.7944 - lr: 0.0009998914320021868
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7942 - loss: 0.8366 - precision_4: 0.7942 - recall_4: 0.7942 - val_accuracy: 0.5339 - val_loss: 0.9356 - val_precision_4: 0.5339 - val_recall_4: 0.5339
# Epoch 3/300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7869 - loss: 0.6624 - precision_4: 0.7869 - recall_4: 0.7869 - lr: 0.0009997556917369366
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7868 - loss: 0.6618 - precision_4: 0.7868 - recall_4: 0.7868 - val_accuracy: 0.5339 - val_loss: 0.8259 - val_precision_4: 0.5339 - val_recall_4: 0.5339
# Epoch 4/300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7818 - loss: 0.5851 - precision_4: 0.7818 - recall_4: 0.7818 - lr: 0.0009995659347623587
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.
300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8781 - loss: 0.2960 - precision_4: 0.8781 - recall_4: 0.8781 - lr: 1.0678363651095424e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8783 - loss: 0.2959 - precision_4: 0.8783 - recall_4: 0.8783 - val_accuracy: 0.7371 - val_loss: 0.8280 - val_precision_4: 0.7371 - val_recall_4: 0.7371
# Epoch 296/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8832 - loss: 0.3040 - precision_4: 0.8832 - recall_4: 0.8832 - lr: 1.0434185242047533e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8832 - loss: 0.3039 - precision_4: 0.8832 - recall_4: 0.8832 - val_accuracy: 0.7371 - val_loss: 0.8293 - val_precision_4: 0.7371 - val_recall_4: 0.7371
# Epoch 297/300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8767 - loss: 0.3069 - precision_4: 0.8767 - recall_4: 0.8767 - lr: 1.0244266377412714e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8770 - loss: 0.3065 - precision_4: 0.8770 - recall_4: 0.8770 - val_accuracy: 0.7371 - val_loss: 0.8283 - val_precision_4: 0.7371 - val_recall_4: 0.7371
# Epoch 298/300
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8677 - loss: 0.3068 - precision_4: 0.8677 - recall_4: 0.8677 - lr: 1.0108547030540649e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8681 - loss: 0.3066 - precision_4: 0.8681 - recall_4: 0.8681 - val_accuracy: 0.7371 - val_loss: 0.8276 - val_precision_4: 0.7371 - val_recall_4: 0.7371
# Epoch 299/300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8878 - loss: 0.2981 - precision_4: 0.8878 - recall_4: 0.8878 - lr: 1.0027144526247866e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8877 - loss: 0.2982 - precision_4: 0.8877 - recall_4: 0.8877 - val_accuracy: 0.7371 - val_loss: 0.8290 - val_precision_4: 0.7371 - val_recall_4: 0.7371
# Epoch 300/300
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8856 - loss: 0.2911 - precision_4: 0.8856 - recall_4: 0.8856 - lr: 1.0000000656873453e-05
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8855 - loss: 0.2912 - precision_4: 0.8855 - recall_4: 0.8855 - val_accuracy: 0.7371 - val_loss: 0.8284 - val_precision_4: 0.7371 - val_recall_4: 0.7371

# %%
fig, axs = plt.subplots(2,1, figsize=(6, 10))
    
# Subplot 1: Plot training & validation accuracy values
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy ' + model_name)

axs[0].axhline(y=max(history.history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.93, f'Max Acc: {max(history.history["accuracy"])}', color='b')  # Add text annotation with the max value

axs[0].axhline(y=max(history.history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.83, f'Max Val Acc: {max(history.history["val_accuracy"])}', color='red')  # Add text annotation with the max value
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend(['Train', 'Val'], loc='upper left')
axs[0].set_ylim(0.5, 1)

# Subplot 2: Plot training & validation loss values
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss ' + model_name)
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['Train', 'Val'], loc='upper left')
axs[1].set_ylim(0, 1)

axs[1].axhline(y=min(history.history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.45, f'Min Val loss: {min(history.history["val_loss"])}', color='red')  # Add text annotation with the max value

axs[1].axhline(y=min(history.history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.1, f'Min loss: {min(history.history["loss"])}', color='b')  # Add text annotation with the max value

# Save the figure with subplots
plt.savefig(f'{plot_folder}\\ACC_LOSS_{model_name}.png')

# Show the plot
plt.show()

# %%
#import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical

# Assuming y_val is one-hot encoded, convert it back to class labels
y_true_classes = np.argmax(val_labels_categorical, axis=1)

# Make predictions on the validation set
y_pred = model.predict(val_data)

# Convert predictions from sigmoid output to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
cmap = plt.cm.Blues
plt.imshow(cm, interpolation='nearest', cmap=cmap)
plt.title('Confusion Matrix ' + model_name)
plt.colorbar()
tick_marks = np.arange(len(np.unique(y_true_classes)))  # this adapts to the number of classes dynamically
plt.xticks(tick_marks, tick_marks)
plt.yticks(tick_marks, tick_marks)

# Labeling the axes
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations inside the squares
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.savefig(f'{plot_folder}\\CM_{model_name}.png')

plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
mm.save_model(model, model_folder, model_name)
# Out:
# Model saved to .\MODELS_3000\M_20_1_3000.keras

# %%
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
print('training time:', (training_time/60), 'minutes')
# Convert the history object to a dictionary
history_dict = history.history

# Add the training time to the dictionary
history_dict['training_time'] = training_time
history_dict['model'] = model_name
history_dict['batch_size'] = batch_size
history_dict['epochs'] = epochs
history_dict['learning_rate'] = initial_learning_rate
history_dict['decay_steps'] = decay_steps
history_dict['alpha'] = alpha
history_dict['loss_function'] = 'binary_crossentropy'
history_dict['optimizer'] = 'Adam'


# Save the dictionary to a JSON file
mm.save_history(history_dict, model_folder, model_name)
# Out:
# Training time: 452.064733505249 seconds
# training time: 7.534412225087483 minutes
# History saved to .\MODELS_3000\M_20_1_3000_history.json

# %%
print('output shape')
print(y_pred.shape)
print('output')
print(y_pred)
# Out:
# output shape
# (502, 2)
# output
# [[2.4952155e-03 9.9750477e-01]
#  [2.1666947e-03 9.9783331e-01]
#  [2.8284589e-07 9.9999976e-01]
#  ...
#  [9.9646926e-01 3.5307386e-03]
#  [6.3977998e-01 3.6022010e-01]
#  [9.9621105e-01 3.7889604e-03]]

# %% [markdown]
# ## changing axis

# %%
models = ['M_1']

# %%
for model in models:
    #m = tf.keras.models.load_model(f'.\\MODELS\\{model}.keras')
    m = mm.load_model(model_folder, model)
    history = mm.load_history(model_folder, model)
    fig, axs = plt.subplots(2,1, figsize=(6, 10))
        
    # Subplot 1: Plot training & validation accuracy values
    axs[0].plot(history['accuracy'])
    axs[0].plot(history['val_accuracy'])
    axs[0].set_title('Model Accuracy ' + model)

    axs[0].axhline(y=max(history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.93, f'Max Acc: {max(history["accuracy"])}', color='b')  # Add text annotation with the max value

    axs[0].axhline(y=max(history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.83, f'Max Val Acc: {max(history["val_accuracy"])}', color='red')  # Add text annotation with the max value
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Val'], loc='upper left')
    axs[0].set_ylim(0.5, 1)

    # Subplot 2: Plot training & validation loss values
    axs[1].plot(history['loss'])
    axs[1].plot(history['val_loss'])
    axs[1].set_title('Model Loss ' + model)
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Val'], loc='upper left')
    axs[1].set_ylim(0, 1)

    axs[1].axhline(y=min(history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.45, f'Min Val loss: {min(history["val_loss"])}', color='red')  # Add text annotation with the max value

    axs[1].axhline(y=min(history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.1, f'Min loss: {min(history["loss"])}', color='b')  # Add text annotation with the max value

    # Save the figure with subplots
    #plt.savefig(f'{plot_folder}\\ACC_LOSS_{model}.png')

    # Show the plot
    plt.show()
# Out:
# Loading model from .\MODELS_3000\M_1.keras
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 for model in models:
#       2     #m = tf.keras.models.load_model(f'.\\MODELS\\{model}.keras')
# ----> 3     m = mm.load_model(model_folder, model)
#       4     history = mm.load_history(model_folder, model)
#       5     fig, axs = plt.subplots(2,1, figsize=(6, 10))
#
# File c:\Users\al385931\OneDrive - Universitat Jaume I\TFM\TFM_NEW\SECOND_CUT\movmus.py:143, in load_model(model_folder, model_name)
#     140 def load_model(model_folder, model_name):
#     141     print(f"Loading model from {model_folder}\\{model_name}.keras")
# --> 143     m = tf.keras.models.load_model(f'{model_folder}\\{model_name}.keras')
#     144     check_model_layers(m)
#     145     return m
#
# File c:\Users\al385931\AppData\Local\anaconda3\envs\tfm2\Lib\site-packages\keras\src\saving\saving_api.py:198, in load_model(filepath, custom_objects, compile, safe_mode)
#     194     return legacy_h5_format.load_model_from_hdf5(
#     195         filepath, custom_objects=custom_objects, compile=compile
#     196     )
#     197 elif str(filepath).endswith(".keras"):
# --> 198     raise ValueError(
#     199         f"File not found: filepath={filepath}. "
#     200         "Please ensure the file is an accessible `.keras` "
#     201         "zip file."
#     202     )
#     203 else:
#     204     raise ValueError(
#     205         f"File format not supported: filepath={filepath}. "
#     206         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     215         "might have a different name)."
#     216     )
#
# ValueError: File not found: filepath=.\MODELS_3000\M_1.keras. Please ensure the file is an accessible `.keras` zip file.
