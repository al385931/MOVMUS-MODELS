# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, MaxPooling1D, GlobalAveragePooling1D, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import compute_class_weight
from sklearn.utils import class_weight
from tensorflow.keras.metrics import Precision, Recall, AUC, SparseCategoricalAccuracy
import time


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import movmus as mm
import movmus2 as mm2

import json

# %% [markdown]
# ## LOADING DATA

# %%
train_data, val_data, test_data = mm.load_data_npz('EMG_2000_data.npz')
# Out:
# shape of training data: (2720, 2000, 7)
# shape of validation data: (502, 2000, 7)
# shape of test data: (661, 2000, 7)

# %%
train_labels = mm.load_labels('training_labels.npz')
val_labels = mm.load_labels('validation_labels.npz')
test_labels = mm.load_labels('test_labels.npz')
print('train labels:', train_labels.shape, 'val labels:', val_labels.shape, 'test labels:', test_labels.shape)
# Out:
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
train_labels.head()
# Out:
#     ID  GRASP_DH
# 0  1.0       1.0
# 1  2.0       1.0
# 2  3.0       1.0
# 3  4.0       1.0
# 4  5.0       1.0

# %%
train_labels_categorical = mm.adjust_labels(train_labels)
val_labels_categorical = mm.adjust_labels(val_labels)
test_labels_categorical = mm.adjust_labels(test_labels)
print('train labels:', train_labels_categorical.shape, 'val labels:', val_labels_categorical.shape, 'test labels:', test_labels_categorical.shape)
# Out:
# Labels after one-hot encoding: (2720, 2)
# Labels after one-hot encoding: (502, 2)
# Labels after one-hot encoding: (661, 2)
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
print(train_labels_categorical)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
first_column = train_labels_categorical[:, 0]
#print(first_column)
second_column = train_labels_categorical[:, 1]
# Count the number of 0s
count_first = np.count_nonzero(first_column == 1)

# Calculate the percentage
percentage_first = (count_first / len(first_column)) * 100

print(f"Percentage of 1s in the first column: {percentage_first}%")

count_second = np.count_nonzero(second_column == 1)
percentage_second = (count_second / len(second_column)) * 100
print(f"Percentage of 1s in the second column: {percentage_second}%")
# Out:
# Percentage of 1s in the first column: 61.360294117647065%
# Percentage of 1s in the second column: 38.63970588235294%

# %% [markdown]
# ## MODEL CREATION

# %%
from tensorflow.keras.regularizers import l2

# %%
model_name = 'M_1_2000'
model_folder = '.\\MODELS_2000'
plot_folder = '.\\PLOTS_2000'

# %%
num_samples = len(train_data)  # Number of training samples
print("Number of training samples:", num_samples)
possible_batch_sizes = [i for i in range(1, num_samples + 1) if num_samples % i == 0]

print("Possible batch sizes that divide evenly:", possible_batch_sizes)
# Out:
# Number of training samples: 2720
# Possible batch sizes that divide evenly: [1, 2, 4, 5, 8, 10, 16, 17, 20, 32, 34, 40, 68, 80, 85, 136, 160, 170, 272, 340, 544, 680, 1360, 2720]

# %%
batch_size = 85
epochs = 300

# %%
# Define the learning rate schedule
initial_learning_rate = 0.001
decay_steps = (num_samples/batch_size)*epochs  # 2752 samples/ 86 bs = 32 --> 32 * 250 epochs = 8000 steps
print("Decay steps:", decay_steps)
alpha = 0.01 

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    alpha=alpha
)
# Out:
# Decay steps: 9600.0

# %%
from tensorflow.keras.callbacks import Callback

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = tf.keras.backend.get_value(self.model.optimizer.learning_rate)
        print(f" - lr: {lr}")

# %%
model = Sequential([
    # Layer 1
    tf.keras.layers.Conv1D(filters=16, kernel_size=10, padding='valid', activation='relu', input_shape=(2000, 7)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    # Layer 2
    tf.keras.layers.Conv1D(filters=32, kernel_size=10, padding='valid', activation='relu'),
    BatchNormalization(),
    GlobalAveragePooling1D(),
    Dropout(0.2),

    # Layer 3
    tf.keras.layers.Dense(32, activation='relu'),

    # Exit layer
    tf.keras.layers.Dense(2, activation='softmax')
])
# Out:
# c:\Users\al385931\AppData\Local\anaconda3\envs\tfm2\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=lr_schedule),
    metrics=['accuracy', Precision(), Recall()] 
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 1991, 16)       │         1,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1991, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 995, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 986, 32)        │         5,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 986, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_3      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,602 (29.70 KB)
#  Trainable params: 7,506 (29.32 KB)
#  Non-trainable params: 96 (384.00 B)

# %% [markdown]
# ## TRAINING

# %%
tf.keras.config.disable_traceback_filtering()

# %%
start_time = time.time()

# Train the model
history = model.fit(
    train_data, train_labels_categorical,
    validation_data=(val_data, val_labels_categorical),
    epochs=epochs,  
    batch_size=batch_size,
    callbacks=[LearningRateLogger()],  
    verbose=1)
    #class_weight = class_weight_dict
#)

end_time = time.time()
# Out:
# Epoch 1/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6928 - loss: 0.6309 - precision_3: 0.6928 - recall_3: 0.6928 - lr: 0.0009999729227274656
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6963 - loss: 0.6274 - precision_3: 0.6963 - recall_3: 0.6963 - val_accuracy: 0.5339 - val_loss: 0.6846 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 2/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7696 - loss: 0.4936 - precision_3: 0.7696 - recall_3: 0.7696 - lr: 0.0009998914320021868
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7705 - loss: 0.4927 - precision_3: 0.7705 - recall_3: 0.7705 - val_accuracy: 0.5518 - val_loss: 0.6779 - val_precision_3: 0.5518 - val_recall_3: 0.5518
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7929 - loss: 0.4578 - precision_3: 0.7929 - recall_3: 0.7929 - lr: 0.0009997556917369366
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7929 - loss: 0.4578 - precision_3: 0.7929 - recall_3: 0.7929 - val_accuracy: 0.5618 - val_loss: 0.6731 - val_precision_3: 0.5618 - val_recall_3: 0.5618
# Epoch 4/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8015 - loss: 0.4392 - precision_3: 0.8015 - recall_3: 0.8015 - lr: 0.0009995659347623587
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8010 - loss: 0.4402 - precision_3: 0.8010 - recall_3: 0.8010 - val_accuracy: 0.5538 - val_loss: 0.6720 - val_precision_3: 0.5538 - val_recall_3: 0.5538
# Epoch 5/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7987 - loss: 0.4495 - precision_3: 0.7987 - recall_3: 0.7987 - lr: 0.0009993216954171658
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7988 - loss: 0.4492 - precision_3: 0.7988 - recall_3: 0.7988 - val_accuracy: 0.5657 - val_loss: 0.6730 - val_precision_3: 0.5657 - val_recall_3: 0.5657
# Epoch 6/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7986 - loss: 0.4370 - precision_3: 0.7986 - recall_3: 0.7986 - lr: 0.0009990233229473233
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7989 - loss: 0.4371 - precision_3: 0.7989 - recall_3: 0.7989 - val_accuracy: 0.5837 - val_loss: 0.6620 - val_precision_3: 0.5837 - val_recall_3: 0.5837
# Epoch 7/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8173 - loss: 0.4225 - precision_3: 0.8173 - recall_3: 0.8173 - lr: 0.0009986707009375095
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8171 - loss: 0.4230 - precision_3: 0.8171 - recall_3: 0.8171 - val_accuracy: 0.5817 - val_loss: 0.6583 - val_precision_3: 0.5817 - val_recall_3: 0.5817
# Epoch 8/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8102 - loss: 0.4164 - precision_3: 0.8102 - recall_3: 0.8102 - lr: 0.0009982639458030462
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8102 - loss: 0.4168 - precision_3: 0.8102 - recall_3: 0.8102 - val_accuracy: 0.5717 - val_loss: 0.6614 - val_precision_3: 0.5717 - val_recall_3: 0.5717
# Epoch 9/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7976 - loss: 0.4386 - precision_3: 0.7976 - recall_3: 0.7976 - lr: 0.0009978031739592552
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7981 - loss: 0.4375 - precision_3: 0.7981 - recall_3: 0.7981 - val_accuracy: 0.5777 - val_loss: 0.6529 - val_precision_3: 0.5777 - val_recall_3: 0.5777
# Epoch 10/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8272 - loss: 0.3901 - precision_3: 0.8272 - recall_3: 0.8272 - lr: 0.0009972883854061365
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8269 - loss: 0.3907 - precision_3: 0.8269 - recall_3: 0.8269 - val_accuracy: 0.6414 - val_loss: 0.6323 - val_precision_3: 0.6414 - val_recall_3: 0.6414
# Epoch 11/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8176 - loss: 0.4088 - precision_3: 0.8176 - recall_3: 0.8176 - lr: 0.0009967195801436901
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8179 - loss: 0.4086 - precision_3: 0.8179 - recall_3: 0.8179 - val_accuracy: 0.6713 - val_loss: 0.6126 - val_precision_3: 0.6713 - val_recall_3: 0.6713
# Epoch 12/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8358 - loss: 0.3908 - precision_3: 0.8358 - recall_3: 0.8358 - lr: 0.0009960968745872378
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8356 - loss: 0.3914 - precision_3: 0.8356 - recall_3: 0.8356 - val_accuracy: 0.6773 - val_loss: 0.6173 - val_precision_3: 0.6773 - val_recall_3: 0.6773
# Epoch 13/300
# 30/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8256 - loss: 0.3958 - precision_3: 0.8256 - recall_3: 0.8256 - lr: 0.0009954202687367797
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8253 - loss: 0.3964 - precision_3: 0.8253 - recall_3: 0.8253 - val_accuracy: 0.6753 - val_loss: 0.5894 - val_precision_3: 0.6753 - val_recall_3: 0.6753
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8201 - loss: 0.4082 - precision_3: 0.8201 - recall_3: 0.8201 - lr: 0.0009946898790076375
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8204 - loss: 0.4075 - precision_3: 0.8204 - recall_3: 0.8204 - val_accuracy: 0.6992 - val_loss: 0.5813 - val_precision_3: 0.6992 - val_recall_3: 0.6992
# Epoch 15/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8166 - loss: 0.3952 - precision_3: 0.8166 - recall_3: 0.8166 - lr: 0.000993905821815133
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8168 - loss: 0.3950 - precision_3: 0.8168 - recall_3: 0.8168 - val_accuracy: 0.7171 - val_loss: 0.5923 - val_precision_3: 0.7171 - val_recall_3: 0.7171
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8230 - loss: 0.3867 - precision_3: 0.8230 - recall_3: 0.8230 - lr: 0.0009930680971592665
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8231 - loss: 0.3868 - precision_3: 0.8231 - recall_3: 0.8231 - val_accuracy: 0.7052 - val_loss: 0.6093 - val_precision_3: 0.7052 - val_recall_3: 0.7052
# Epoch 17/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8222 - loss: 0.4013 - precision_3: 0.8222 - recall_3: 0.8222 - lr: 0.0009921768214553595
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8232 - loss: 0.3999 - precision_3: 0.8232 - recall_3: 0.8232 - val_accuracy: 0.6892 - val_loss: 0.5885 - val_precision_3: 0.6892 - val_recall_3: 0.6892
# Epoch 18/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8343 - loss: 0.3901 - precision_3: 0.8343 - recall_3: 0.8343 - lr: 0.0009912322275340557
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8344 - loss: 0.3891 - precision_3: 0.8344 - recall_3: 0.8344 - val_accuracy: 0.7470 - val_loss: 0.6684 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 19/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8470 - loss: 0.3576 - precision_3: 0.8470 - recall_3: 0.8470 - lr: 0.0009902341989800334
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8468 - loss: 0.3578 - precision_3: 0.8468 - recall_3: 0.8468 - val_accuracy: 0.7410 - val_loss: 0.6315 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 20/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8382 - loss: 0.3596 - precision_3: 0.8382 - recall_3: 0.8382 - lr: 0.000989183085039258
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8383 - loss: 0.3600 - precision_3: 0.8383 - recall_3: 0.8383 - val_accuracy: 0.7390 - val_loss: 0.5928 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 21/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8435 - loss: 0.3700 - precision_3: 0.8435 - recall_3: 0.8435 - lr: 0.0009880787692964077
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8436 - loss: 0.3697 - precision_3: 0.8436 - recall_3: 0.8436 - val_accuracy: 0.7171 - val_loss: 0.6668 - val_precision_3: 0.7171 - val_recall_3: 0.7171
# Epoch 22/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8371 - loss: 0.3722 - precision_3: 0.8371 - recall_3: 0.8371 - lr: 0.000986921600997448
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8367 - loss: 0.3727 - precision_3: 0.8367 - recall_3: 0.8367 - val_accuracy: 0.7311 - val_loss: 0.5565 - val_precision_3: 0.7311 - val_recall_3: 0.7311
# Epoch 23/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8331 - loss: 0.3707 - precision_3: 0.8331 - recall_3: 0.8331 - lr: 0.000985711463727057
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8333 - loss: 0.3703 - precision_3: 0.8333 - recall_3: 0.8333 - val_accuracy: 0.7191 - val_loss: 0.6607 - val_precision_3: 0.7191 - val_recall_3: 0.7191
# Epoch 24/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8501 - loss: 0.3472 - precision_3: 0.8501 - recall_3: 0.8501 - lr: 0.0009844487067312002
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8498 - loss: 0.3480 - precision_3: 0.8498 - recall_3: 0.8498 - val_accuracy: 0.7231 - val_loss: 0.7238 - val_precision_3: 0.7231 - val_recall_3: 0.7231
# Epoch 25/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8559 - loss: 0.3423 - precision_3: 0.8559 - recall_3: 0.8559 - lr: 0.0009831333300098777
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8551 - loss: 0.3434 - precision_3: 0.8551 - recall_3: 0.8551 - val_accuracy: 0.7390 - val_loss: 0.7351 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 26/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8414 - loss: 0.3743 - precision_3: 0.8414 - recall_3: 0.8414 - lr: 0.0009817654499784112
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8418 - loss: 0.3730 - precision_3: 0.8418 - recall_3: 0.8418 - val_accuracy: 0.7331 - val_loss: 0.7489 - val_precision_3: 0.7331 - val_recall_3: 0.7331
# Epoch 27/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8357 - loss: 0.3785 - precision_3: 0.8357 - recall_3: 0.8357 - lr: 0.0009803454158827662
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8365 - loss: 0.3768 - precision_3: 0.8365 - recall_3: 0.8365 - val_accuracy: 0.7311 - val_loss: 0.7583 - val_precision_3: 0.7311 - val_recall_3: 0.7311
# Epoch 28/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8556 - loss: 0.3388 - precision_3: 0.8556 - recall_3: 0.8556 - lr: 0.0009788732277229428
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8552 - loss: 0.3398 - precision_3: 0.8552 - recall_3: 0.8552 - val_accuracy: 0.7351 - val_loss: 0.7014 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 29/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8616 - loss: 0.3393 - precision_3: 0.8616 - recall_3: 0.8616 - lr: 0.0009773490019142628
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8610 - loss: 0.3399 - precision_3: 0.8610 - recall_3: 0.8610 - val_accuracy: 0.7191 - val_loss: 0.7828 - val_precision_3: 0.7191 - val_recall_3: 0.7191
# Epoch 30/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8454 - loss: 0.3465 - precision_3: 0.8454 - recall_3: 0.8454 - lr: 0.0009757730294950306
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8448 - loss: 0.3470 - precision_3: 0.8448 - recall_3: 0.8448 - val_accuracy: 0.7271 - val_loss: 0.6298 - val_precision_3: 0.7271 - val_recall_3: 0.7271
# Epoch 31/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8546 - loss: 0.3393 - precision_3: 0.8546 - recall_3: 0.8546 - lr: 0.0009741454268805683
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8544 - loss: 0.3399 - precision_3: 0.8544 - recall_3: 0.8544 - val_accuracy: 0.7390 - val_loss: 0.7854 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 32/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8534 - loss: 0.3515 - precision_3: 0.8534 - recall_3: 0.8534 - lr: 0.0009724663104861975
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8530 - loss: 0.3516 - precision_3: 0.8530 - recall_3: 0.8530 - val_accuracy: 0.7311 - val_loss: 0.7840 - val_precision_3: 0.7311 - val_recall_3: 0.7311
# Epoch 33/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8546 - loss: 0.3449 - precision_3: 0.8546 - recall_3: 0.8546 - lr: 0.0009707360295578837
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8542 - loss: 0.3453 - precision_3: 0.8542 - recall_3: 0.8542 - val_accuracy: 0.7291 - val_loss: 0.7389 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8496 - loss: 0.3489 - precision_3: 0.8496 - recall_3: 0.8496 - lr: 0.0009689545840956271
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8498 - loss: 0.3487 - precision_3: 0.8498 - recall_3: 0.8498 - val_accuracy: 0.7490 - val_loss: 0.8195 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 35/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8516 - loss: 0.3359 - precision_3: 0.8516 - recall_3: 0.8516 - lr: 0.0009671223815530539
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8513 - loss: 0.3365 - precision_3: 0.8513 - recall_3: 0.8513 - val_accuracy: 0.7291 - val_loss: 0.7622 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 36/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8446 - loss: 0.3645 - precision_3: 0.8446 - recall_3: 0.8446 - lr: 0.0009652393637225032
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8450 - loss: 0.3636 - precision_3: 0.8450 - recall_3: 0.8450 - val_accuracy: 0.7211 - val_loss: 0.7854 - val_precision_3: 0.7211 - val_recall_3: 0.7211
# Epoch 37/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8528 - loss: 0.3453 - precision_3: 0.8528 - recall_3: 0.8528 - lr: 0.0009633059962652624
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8528 - loss: 0.3452 - precision_3: 0.8528 - recall_3: 0.8528 - val_accuracy: 0.7331 - val_loss: 0.8159 - val_precision_3: 0.7331 - val_recall_3: 0.7331
# Epoch 38/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8575 - loss: 0.3259 - precision_3: 0.8575 - recall_3: 0.8575 - lr: 0.0009613222791813314
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8572 - loss: 0.3266 - precision_3: 0.8572 - recall_3: 0.8572 - val_accuracy: 0.7371 - val_loss: 0.9341 - val_precision_3: 0.7371 - val_recall_3: 0.7371
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8432 - loss: 0.3536 - precision_3: 0.8432 - recall_3: 0.8432 - lr: 0.0009592885617166758
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8435 - loss: 0.3533 - precision_3: 0.8435 - recall_3: 0.8435 - val_accuracy: 0.7271 - val_loss: 0.7297 - val_precision_3: 0.7271 - val_recall_3: 0.7271
# Epoch 40/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8542 - loss: 0.3264 - precision_3: 0.8542 - recall_3: 0.8542 - lr: 0.0009572049602866173
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8544 - loss: 0.3269 - precision_3: 0.8544 - recall_3: 0.8544 - val_accuracy: 0.7410 - val_loss: 0.8176 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 41/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8573 - loss: 0.3225 - precision_3: 0.8573 - recall_3: 0.8573 - lr: 0.0009550719405524433
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8572 - loss: 0.3227 - precision_3: 0.8572 - recall_3: 0.8572 - val_accuracy: 0.7351 - val_loss: 0.7345 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 42/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8472 - loss: 0.3447 - precision_3: 0.8472 - recall_3: 0.8472 - lr: 0.0009528895025141537
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8478 - loss: 0.3442 - precision_3: 0.8478 - recall_3: 0.8478 - val_accuracy: 0.7470 - val_loss: 0.8520 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 43/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8566 - loss: 0.3301 - precision_3: 0.8566 - recall_3: 0.8566 - lr: 0.0009506578790023923
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8565 - loss: 0.3304 - precision_3: 0.8565 - recall_3: 0.8565 - val_accuracy: 0.7390 - val_loss: 0.7237 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 44/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8616 - loss: 0.3232 - precision_3: 0.8616 - recall_3: 0.8616 - lr: 0.0009483773610554636
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8610 - loss: 0.3240 - precision_3: 0.8610 - recall_3: 0.8610 - val_accuracy: 0.7430 - val_loss: 0.7479 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 45/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8580 - loss: 0.3416 - precision_3: 0.8580 - recall_3: 0.8580 - lr: 0.0009460482397116721
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8579 - loss: 0.3412 - precision_3: 0.8579 - recall_3: 0.8579 - val_accuracy: 0.7430 - val_loss: 0.8025 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 46/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8693 - loss: 0.3085 - precision_3: 0.8693 - recall_3: 0.8693 - lr: 0.0009436708060093224
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8688 - loss: 0.3096 - precision_3: 0.8688 - recall_3: 0.8688 - val_accuracy: 0.7430 - val_loss: 0.7345 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 47/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8621 - loss: 0.3364 - precision_3: 0.8621 - recall_3: 0.8621 - lr: 0.0009412452345713973
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8620 - loss: 0.3359 - precision_3: 0.8620 - recall_3: 0.8620 - val_accuracy: 0.7351 - val_loss: 0.9089 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 48/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8548 - loss: 0.3324 - precision_3: 0.8548 - recall_3: 0.8548 - lr: 0.0009387718164362013
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8546 - loss: 0.3327 - precision_3: 0.8546 - recall_3: 0.8546 - val_accuracy: 0.7291 - val_loss: 0.8036 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 49/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8580 - loss: 0.3343 - precision_3: 0.8580 - recall_3: 0.8580 - lr: 0.0009362508426420391
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8580 - loss: 0.3339 - precision_3: 0.8580 - recall_3: 0.8580 - val_accuracy: 0.7510 - val_loss: 0.7206 - val_precision_3: 0.7510 - val_recall_3: 0.7510
# Epoch 50/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8671 - loss: 0.3203 - precision_3: 0.8671 - recall_3: 0.8671 - lr: 0.000933682662434876
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8669 - loss: 0.3207 - precision_3: 0.8669 - recall_3: 0.8669 - val_accuracy: 0.7430 - val_loss: 0.7177 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 51/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8718 - loss: 0.3147 - precision_3: 0.8718 - recall_3: 0.8718 - lr: 0.0009310673922300339
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8711 - loss: 0.3158 - precision_3: 0.8711 - recall_3: 0.8711 - val_accuracy: 0.7490 - val_loss: 0.8711 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 52/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8695 - loss: 0.3254 - precision_3: 0.8695 - recall_3: 0.8695 - lr: 0.0009284053812734783
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8690 - loss: 0.3253 - precision_3: 0.8690 - recall_3: 0.8690 - val_accuracy: 0.7410 - val_loss: 0.8066 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 53/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8672 - loss: 0.3184 - precision_3: 0.8672 - recall_3: 0.8672 - lr: 0.0009256969206035137
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8673 - loss: 0.3188 - precision_3: 0.8673 - recall_3: 0.8673 - val_accuracy: 0.7131 - val_loss: 0.9306 - val_precision_3: 0.7131 - val_recall_3: 0.7131
# Epoch 54/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8527 - loss: 0.3296 - precision_3: 0.8527 - recall_3: 0.8527 - lr: 0.0009229423594661057
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8530 - loss: 0.3296 - precision_3: 0.8530 - recall_3: 0.8530 - val_accuracy: 0.7351 - val_loss: 0.8804 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 55/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8666 - loss: 0.3093 - precision_3: 0.8666 - recall_3: 0.8666 - lr: 0.0009201419306918979
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8662 - loss: 0.3101 - precision_3: 0.8662 - recall_3: 0.8662 - val_accuracy: 0.7530 - val_loss: 0.6901 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 56/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8763 - loss: 0.3123 - precision_3: 0.8763 - recall_3: 0.8763 - lr: 0.0009172960999421775
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8757 - loss: 0.3129 - precision_3: 0.8757 - recall_3: 0.8757 - val_accuracy: 0.7490 - val_loss: 0.8223 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 57/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8722 - loss: 0.3137 - precision_3: 0.8722 - recall_3: 0.8722 - lr: 0.0009144049254246056
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8716 - loss: 0.3144 - precision_3: 0.8716 - recall_3: 0.8716 - val_accuracy: 0.7530 - val_loss: 0.7426 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 58/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8701 - loss: 0.3208 - precision_3: 0.8701 - recall_3: 0.8701 - lr: 0.0009114688728004694
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8701 - loss: 0.3207 - precision_3: 0.8701 - recall_3: 0.8701 - val_accuracy: 0.7530 - val_loss: 0.7071 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 59/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8581 - loss: 0.3287 - precision_3: 0.8581 - recall_3: 0.8581 - lr: 0.0009084882913157344
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8582 - loss: 0.3286 - precision_3: 0.8582 - recall_3: 0.8582 - val_accuracy: 0.7510 - val_loss: 0.7440 - val_precision_3: 0.7510 - val_recall_3: 0.7510
# Epoch 60/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8700 - loss: 0.3076 - precision_3: 0.8700 - recall_3: 0.8700 - lr: 0.0009054634138010442
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8697 - loss: 0.3079 - precision_3: 0.8697 - recall_3: 0.8697 - val_accuracy: 0.7351 - val_loss: 0.8842 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 61/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8790 - loss: 0.3151 - precision_3: 0.8790 - recall_3: 0.8790 - lr: 0.0009023947059176862
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8782 - loss: 0.3152 - precision_3: 0.8782 - recall_3: 0.8782 - val_accuracy: 0.7530 - val_loss: 0.8246 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 62/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8607 - loss: 0.3206 - precision_3: 0.8607 - recall_3: 0.8607 - lr: 0.0008992823422886431
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8608 - loss: 0.3204 - precision_3: 0.8608 - recall_3: 0.8608 - val_accuracy: 0.7470 - val_loss: 0.7914 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 63/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8755 - loss: 0.3083 - precision_3: 0.8755 - recall_3: 0.8755 - lr: 0.0008961267885752022
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8748 - loss: 0.3087 - precision_3: 0.8748 - recall_3: 0.8748 - val_accuracy: 0.7450 - val_loss: 0.7856 - val_precision_3: 0.7450 - val_recall_3: 0.7450
# Epoch 64/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8611 - loss: 0.3102 - precision_3: 0.8611 - recall_3: 0.8611 - lr: 0.0008929282776080072
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8611 - loss: 0.3109 - precision_3: 0.8611 - recall_3: 0.8611 - val_accuracy: 0.7291 - val_loss: 0.8043 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 65/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8762 - loss: 0.3180 - precision_3: 0.8762 - recall_3: 0.8762 - lr: 0.0008896872168406844
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8755 - loss: 0.3181 - precision_3: 0.8755 - recall_3: 0.8755 - val_accuracy: 0.7430 - val_loss: 0.9280 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 66/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8695 - loss: 0.3159 - precision_3: 0.8695 - recall_3: 0.8695 - lr: 0.0008864041301421821
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8698 - loss: 0.3157 - precision_3: 0.8698 - recall_3: 0.8698 - val_accuracy: 0.7669 - val_loss: 0.8184 - val_precision_3: 0.7669 - val_recall_3: 0.7669
# Epoch 67/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8633 - loss: 0.3127 - precision_3: 0.8633 - recall_3: 0.8633 - lr: 0.0008830790757201612
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8635 - loss: 0.3127 - precision_3: 0.8635 - recall_3: 0.8635 - val_accuracy: 0.7550 - val_loss: 0.7894 - val_precision_3: 0.7550 - val_recall_3: 0.7550
# Epoch 68/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8699 - loss: 0.3000 - precision_3: 0.8699 - recall_3: 0.8699 - lr: 0.0008797125774435699
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8692 - loss: 0.3014 - precision_3: 0.8692 - recall_3: 0.8692 - val_accuracy: 0.7271 - val_loss: 0.9853 - val_precision_3: 0.7271 - val_recall_3: 0.7271
# Epoch 69/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8548 - loss: 0.3154 - precision_3: 0.8548 - recall_3: 0.8548 - lr: 0.0008763050427660346
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8552 - loss: 0.3155 - precision_3: 0.8552 - recall_3: 0.8552 - val_accuracy: 0.7331 - val_loss: 1.0143 - val_precision_3: 0.7331 - val_recall_3: 0.7331
# Epoch 70/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8785 - loss: 0.2938 - precision_3: 0.8785 - recall_3: 0.8785 - lr: 0.000872856704518199
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8781 - loss: 0.2948 - precision_3: 0.8781 - recall_3: 0.8781 - val_accuracy: 0.7530 - val_loss: 0.7200 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 71/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8672 - loss: 0.3173 - precision_3: 0.8672 - recall_3: 0.8672 - lr: 0.0008693681447766721
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8671 - loss: 0.3172 - precision_3: 0.8671 - recall_3: 0.8671 - val_accuracy: 0.7629 - val_loss: 0.7581 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 72/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8769 - loss: 0.3086 - precision_3: 0.8769 - recall_3: 0.8769 - lr: 0.0008658395381644368
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8765 - loss: 0.3089 - precision_3: 0.8765 - recall_3: 0.8765 - val_accuracy: 0.7590 - val_loss: 0.9049 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 73/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8673 - loss: 0.2993 - precision_3: 0.8673 - recall_3: 0.8673 - lr: 0.0008622713503427804
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8673 - loss: 0.2996 - precision_3: 0.8673 - recall_3: 0.8673 - val_accuracy: 0.7590 - val_loss: 0.8724 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 74/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8737 - loss: 0.3000 - precision_3: 0.8737 - recall_3: 0.8737 - lr: 0.0008586639887653291
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8734 - loss: 0.3006 - precision_3: 0.8734 - recall_3: 0.8734 - val_accuracy: 0.7649 - val_loss: 0.7320 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 75/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8762 - loss: 0.2953 - precision_3: 0.8762 - recall_3: 0.8762 - lr: 0.0008550179190933704
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8760 - loss: 0.2955 - precision_3: 0.8760 - recall_3: 0.8760 - val_accuracy: 0.7649 - val_loss: 0.8144 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 76/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8806 - loss: 0.2980 - precision_3: 0.8806 - recall_3: 0.8806 - lr: 0.0008513334323652089
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8803 - loss: 0.2981 - precision_3: 0.8803 - recall_3: 0.8803 - val_accuracy: 0.7550 - val_loss: 0.8828 - val_precision_3: 0.7550 - val_recall_3: 0.7550
# Epoch 77/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8803 - loss: 0.3031 - precision_3: 0.8803 - recall_3: 0.8803 - lr: 0.0008476109360344708
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8802 - loss: 0.3029 - precision_3: 0.8802 - recall_3: 0.8802 - val_accuracy: 0.7629 - val_loss: 0.7177 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 78/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8685 - loss: 0.3073 - precision_3: 0.8685 - recall_3: 0.8685 - lr: 0.0008438508957624435
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8684 - loss: 0.3080 - precision_3: 0.8684 - recall_3: 0.8684 - val_accuracy: 0.7490 - val_loss: 0.7243 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 79/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8765 - loss: 0.3131 - precision_3: 0.8765 - recall_3: 0.8765 - lr: 0.0008400536607950926
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8765 - loss: 0.3125 - precision_3: 0.8765 - recall_3: 0.8765 - val_accuracy: 0.7371 - val_loss: 0.8475 - val_precision_3: 0.7371 - val_recall_3: 0.7371
# Epoch 80/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8750 - loss: 0.2818 - precision_3: 0.8750 - recall_3: 0.8750 - lr: 0.0008362196385860443
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8748 - loss: 0.2832 - precision_3: 0.8748 - recall_3: 0.8748 - val_accuracy: 0.7689 - val_loss: 0.8849 - val_precision_3: 0.7689 - val_recall_3: 0.7689
# Epoch 81/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8785 - loss: 0.2979 - precision_3: 0.8785 - recall_3: 0.8785 - lr: 0.0008323494112119079
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8783 - loss: 0.2984 - precision_3: 0.8783 - recall_3: 0.8783 - val_accuracy: 0.7470 - val_loss: 0.8298 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 82/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8843 - loss: 0.2771 - precision_3: 0.8843 - recall_3: 0.8843 - lr: 0.0008284432115033269
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8837 - loss: 0.2783 - precision_3: 0.8837 - recall_3: 0.8837 - val_accuracy: 0.7331 - val_loss: 0.8452 - val_precision_3: 0.7331 - val_recall_3: 0.7331
# Epoch 83/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8725 - loss: 0.2989 - precision_3: 0.8725 - recall_3: 0.8725 - lr: 0.0008245016215369105
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8724 - loss: 0.2992 - precision_3: 0.8724 - recall_3: 0.8724 - val_accuracy: 0.7470 - val_loss: 1.0123 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 84/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8764 - loss: 0.2959 - precision_3: 0.8764 - recall_3: 0.8764 - lr: 0.0008205249323509634
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8763 - loss: 0.2960 - precision_3: 0.8763 - recall_3: 0.8763 - val_accuracy: 0.7590 - val_loss: 0.9017 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 85/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8900 - loss: 0.2721 - precision_3: 0.8900 - recall_3: 0.8900 - lr: 0.0008165136096067727
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8891 - loss: 0.2734 - precision_3: 0.8891 - recall_3: 0.8891 - val_accuracy: 0.7171 - val_loss: 1.0708 - val_precision_3: 0.7171 - val_recall_3: 0.7171
# Epoch 86/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8894 - loss: 0.2956 - precision_3: 0.8894 - recall_3: 0.8894 - lr: 0.0008124682353809476
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8886 - loss: 0.2960 - precision_3: 0.8886 - recall_3: 0.8886 - val_accuracy: 0.7530 - val_loss: 0.9131 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 87/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8708 - loss: 0.2984 - precision_3: 0.8708 - recall_3: 0.8708 - lr: 0.0008083890425041318
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8711 - loss: 0.2985 - precision_3: 0.8711 - recall_3: 0.8711 - val_accuracy: 0.7470 - val_loss: 0.8250 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 88/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8664 - loss: 0.3008 - precision_3: 0.8664 - recall_3: 0.8664 - lr: 0.0008042766130529344
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8670 - loss: 0.3007 - precision_3: 0.8670 - recall_3: 0.8670 - val_accuracy: 0.7610 - val_loss: 0.9439 - val_precision_3: 0.7610 - val_recall_3: 0.7610
# Epoch 89/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8692 - loss: 0.2946 - precision_3: 0.8692 - recall_3: 0.8692 - lr: 0.0008001312962733209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8692 - loss: 0.2948 - precision_3: 0.8692 - recall_3: 0.8692 - val_accuracy: 0.7530 - val_loss: 0.9802 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 90/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8664 - loss: 0.3036 - precision_3: 0.8664 - recall_3: 0.8664 - lr: 0.0007959537324495614
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8664 - loss: 0.3035 - precision_3: 0.8664 - recall_3: 0.8664 - val_accuracy: 0.7590 - val_loss: 0.8596 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 91/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8811 - loss: 0.2938 - precision_3: 0.8811 - recall_3: 0.8811 - lr: 0.0007917441544122994
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8808 - loss: 0.2940 - precision_3: 0.8808 - recall_3: 0.8808 - val_accuracy: 0.7450 - val_loss: 0.9676 - val_precision_3: 0.7450 - val_recall_3: 0.7450
# Epoch 92/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8736 - loss: 0.2954 - precision_3: 0.8736 - recall_3: 0.8736 - lr: 0.0007875032024458051
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8739 - loss: 0.2955 - precision_3: 0.8739 - recall_3: 0.8739 - val_accuracy: 0.7410 - val_loss: 0.9738 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 93/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8698 - loss: 0.2927 - precision_3: 0.8698 - recall_3: 0.8698 - lr: 0.0007832312840037048
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8698 - loss: 0.2934 - precision_3: 0.8698 - recall_3: 0.8698 - val_accuracy: 0.7470 - val_loss: 0.8186 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 94/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8826 - loss: 0.2785 - precision_3: 0.8826 - recall_3: 0.8826 - lr: 0.0007789288647472858
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8823 - loss: 0.2791 - precision_3: 0.8823 - recall_3: 0.8823 - val_accuracy: 0.7490 - val_loss: 0.8549 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 95/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8767 - loss: 0.2900 - precision_3: 0.8767 - recall_3: 0.8767 - lr: 0.0007745962939225137
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8765 - loss: 0.2903 - precision_3: 0.8765 - recall_3: 0.8765 - val_accuracy: 0.7629 - val_loss: 0.8842 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 96/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8624 - loss: 0.3025 - precision_3: 0.8624 - recall_3: 0.8624 - lr: 0.0007702342700213194
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8633 - loss: 0.3014 - precision_3: 0.8633 - recall_3: 0.8633 - val_accuracy: 0.7390 - val_loss: 0.8651 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 97/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8773 - loss: 0.2935 - precision_3: 0.8773 - recall_3: 0.8773 - lr: 0.0007658432004973292
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8772 - loss: 0.2936 - precision_3: 0.8772 - recall_3: 0.8772 - val_accuracy: 0.7092 - val_loss: 0.9735 - val_precision_3: 0.7092 - val_recall_3: 0.7092
# Epoch 98/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8799 - loss: 0.2842 - precision_3: 0.8799 - recall_3: 0.8799 - lr: 0.0007614234345965087
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8795 - loss: 0.2848 - precision_3: 0.8795 - recall_3: 0.8795 - val_accuracy: 0.7590 - val_loss: 0.9175 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 99/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8810 - loss: 0.2835 - precision_3: 0.8810 - recall_3: 0.8810 - lr: 0.0007569754961878061
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8807 - loss: 0.2841 - precision_3: 0.8807 - recall_3: 0.8807 - val_accuracy: 0.7490 - val_loss: 0.8983 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 100/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8677 - loss: 0.3089 - precision_3: 0.8677 - recall_3: 0.8677 - lr: 0.0007525000255554914
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8681 - loss: 0.3080 - precision_3: 0.8681 - recall_3: 0.8681 - val_accuracy: 0.7649 - val_loss: 0.9339 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 101/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8830 - loss: 0.2797 - precision_3: 0.8830 - recall_3: 0.8830 - lr: 0.0007479973719455302
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8825 - loss: 0.2807 - precision_3: 0.8825 - recall_3: 0.8825 - val_accuracy: 0.7590 - val_loss: 0.8340 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 102/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8732 - loss: 0.2947 - precision_3: 0.8732 - recall_3: 0.8732 - lr: 0.0007434680592268705
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8729 - loss: 0.2952 - precision_3: 0.8729 - recall_3: 0.8729 - val_accuracy: 0.7570 - val_loss: 0.9119 - val_precision_3: 0.7570 - val_recall_3: 0.7570
# Epoch 103/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8738 - loss: 0.2910 - precision_3: 0.8738 - recall_3: 0.8738 - lr: 0.0007389126694761217
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8739 - loss: 0.2907 - precision_3: 0.8739 - recall_3: 0.8739 - val_accuracy: 0.7470 - val_loss: 0.9372 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 104/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8759 - loss: 0.2895 - precision_3: 0.8759 - recall_3: 0.8759 - lr: 0.00073433161014691
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8760 - loss: 0.2889 - precision_3: 0.8760 - recall_3: 0.8760 - val_accuracy: 0.7470 - val_loss: 0.9499 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 105/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8791 - loss: 0.2957 - precision_3: 0.8791 - recall_3: 0.8791 - lr: 0.0007297253469005227
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8791 - loss: 0.2953 - precision_3: 0.8791 - recall_3: 0.8791 - val_accuracy: 0.7211 - val_loss: 0.9691 - val_precision_3: 0.7211 - val_recall_3: 0.7211
# Epoch 106/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8848 - loss: 0.2792 - precision_3: 0.8848 - recall_3: 0.8848 - lr: 0.0007250944036059082
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8840 - loss: 0.2807 - precision_3: 0.8840 - recall_3: 0.8840 - val_accuracy: 0.7131 - val_loss: 0.9678 - val_precision_3: 0.7131 - val_recall_3: 0.7131
# Epoch 107/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8761 - loss: 0.2895 - precision_3: 0.8761 - recall_3: 0.8761 - lr: 0.0007204394205473363
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8761 - loss: 0.2894 - precision_3: 0.8761 - recall_3: 0.8761 - val_accuracy: 0.7629 - val_loss: 0.9273 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 108/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8724 - loss: 0.2938 - precision_3: 0.8724 - recall_3: 0.8724 - lr: 0.0007157607469707727
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8728 - loss: 0.2934 - precision_3: 0.8728 - recall_3: 0.8728 - val_accuracy: 0.7689 - val_loss: 1.0059 - val_precision_3: 0.7689 - val_recall_3: 0.7689
# Epoch 109/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8868 - loss: 0.2746 - precision_3: 0.8868 - recall_3: 0.8868 - lr: 0.0007110590231604874
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8863 - loss: 0.2752 - precision_3: 0.8863 - recall_3: 0.8863 - val_accuracy: 0.7490 - val_loss: 0.9104 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 110/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8598 - loss: 0.2981 - precision_3: 0.8598 - recall_3: 0.8598 - lr: 0.0007063345983624458
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8606 - loss: 0.2976 - precision_3: 0.8606 - recall_3: 0.8606 - val_accuracy: 0.7470 - val_loss: 0.8906 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 111/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8584 - loss: 0.3162 - precision_3: 0.8584 - recall_3: 0.8584 - lr: 0.0007015882292762399
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8591 - loss: 0.3150 - precision_3: 0.8591 - recall_3: 0.8591 - val_accuracy: 0.7590 - val_loss: 0.9915 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 112/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8733 - loss: 0.2928 - precision_3: 0.8733 - recall_3: 0.8733 - lr: 0.0006968202069401741
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8739 - loss: 0.2920 - precision_3: 0.8739 - recall_3: 0.8739 - val_accuracy: 0.7530 - val_loss: 0.9955 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 113/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8780 - loss: 0.2927 - precision_3: 0.8780 - recall_3: 0.8780 - lr: 0.0006920311716385186
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8780 - loss: 0.2923 - precision_3: 0.8780 - recall_3: 0.8780 - val_accuracy: 0.7669 - val_loss: 0.8716 - val_precision_3: 0.7669 - val_recall_3: 0.7669
# Epoch 114/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8740 - loss: 0.2786 - precision_3: 0.8740 - recall_3: 0.8740 - lr: 0.0006872217054478824
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8740 - loss: 0.2792 - precision_3: 0.8740 - recall_3: 0.8740 - val_accuracy: 0.7510 - val_loss: 0.8931 - val_precision_3: 0.7510 - val_recall_3: 0.7510
# Epoch 115/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8889 - loss: 0.2689 - precision_3: 0.8889 - recall_3: 0.8889 - lr: 0.0006823921576142311
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8885 - loss: 0.2699 - precision_3: 0.8885 - recall_3: 0.8885 - val_accuracy: 0.7610 - val_loss: 0.8583 - val_precision_3: 0.7610 - val_recall_3: 0.7610
# Epoch 116/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8893 - loss: 0.2768 - precision_3: 0.8893 - recall_3: 0.8893 - lr: 0.0006775431684218347
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8890 - loss: 0.2770 - precision_3: 0.8890 - recall_3: 0.8890 - val_accuracy: 0.7610 - val_loss: 0.9003 - val_precision_3: 0.7610 - val_recall_3: 0.7610
# Epoch 117/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8896 - loss: 0.2744 - precision_3: 0.8896 - recall_3: 0.8896 - lr: 0.0006726753199473023
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8891 - loss: 0.2748 - precision_3: 0.8891 - recall_3: 0.8891 - val_accuracy: 0.7410 - val_loss: 1.1655 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 118/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8741 - loss: 0.2903 - precision_3: 0.8741 - recall_3: 0.8741 - lr: 0.0006677889614365995
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8744 - loss: 0.2899 - precision_3: 0.8744 - recall_3: 0.8744 - val_accuracy: 0.7530 - val_loss: 0.9845 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 119/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8904 - loss: 0.2598 - precision_3: 0.8904 - recall_3: 0.8904 - lr: 0.000662884849589318
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8899 - loss: 0.2604 - precision_3: 0.8899 - recall_3: 0.8899 - val_accuracy: 0.7490 - val_loss: 0.9274 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 120/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8878 - loss: 0.2752 - precision_3: 0.8878 - recall_3: 0.8878 - lr: 0.0006579634500667453
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8871 - loss: 0.2763 - precision_3: 0.8871 - recall_3: 0.8871 - val_accuracy: 0.7371 - val_loss: 0.9538 - val_precision_3: 0.7371 - val_recall_3: 0.7371
# Epoch 121/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8746 - loss: 0.2910 - precision_3: 0.8746 - recall_3: 0.8746 - lr: 0.0006530252285301685
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8748 - loss: 0.2907 - precision_3: 0.8748 - recall_3: 0.8748 - val_accuracy: 0.7709 - val_loss: 0.9818 - val_precision_3: 0.7709 - val_recall_3: 0.7709
# Epoch 122/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8747 - loss: 0.2909 - precision_3: 0.8747 - recall_3: 0.8747 - lr: 0.000648070708848536
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8753 - loss: 0.2900 - precision_3: 0.8753 - recall_3: 0.8753 - val_accuracy: 0.7390 - val_loss: 1.1073 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 123/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8888 - loss: 0.2663 - precision_3: 0.8888 - recall_3: 0.8888 - lr: 0.0006431006477214396
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8884 - loss: 0.2668 - precision_3: 0.8884 - recall_3: 0.8884 - val_accuracy: 0.7490 - val_loss: 1.0194 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 124/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8711 - loss: 0.2820 - precision_3: 0.8711 - recall_3: 0.8711 - lr: 0.0006381153361871839
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8713 - loss: 0.2817 - precision_3: 0.8713 - recall_3: 0.8713 - val_accuracy: 0.7291 - val_loss: 0.9938 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 125/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8782 - loss: 0.2870 - precision_3: 0.8782 - recall_3: 0.8782 - lr: 0.0006331154727376997
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8784 - loss: 0.2866 - precision_3: 0.8784 - recall_3: 0.8784 - val_accuracy: 0.7490 - val_loss: 0.9883 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 126/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8866 - loss: 0.2689 - precision_3: 0.8866 - recall_3: 0.8866 - lr: 0.0006281015230342746
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8863 - loss: 0.2694 - precision_3: 0.8863 - recall_3: 0.8863 - val_accuracy: 0.7430 - val_loss: 0.8683 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 127/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8859 - loss: 0.2740 - precision_3: 0.8859 - recall_3: 0.8859 - lr: 0.0006230740691535175
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8857 - loss: 0.2745 - precision_3: 0.8857 - recall_3: 0.8857 - val_accuracy: 0.7510 - val_loss: 0.9896 - val_precision_3: 0.7510 - val_recall_3: 0.7510
# Epoch 128/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8798 - loss: 0.2817 - precision_3: 0.8798 - recall_3: 0.8798 - lr: 0.0006180336931720376
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8799 - loss: 0.2816 - precision_3: 0.8799 - recall_3: 0.8799 - val_accuracy: 0.7530 - val_loss: 0.8951 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 129/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8901 - loss: 0.2668 - precision_3: 0.8901 - recall_3: 0.8901 - lr: 0.0006129809189587831
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8896 - loss: 0.2676 - precision_3: 0.8896 - recall_3: 0.8896 - val_accuracy: 0.7530 - val_loss: 0.8053 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 130/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8838 - loss: 0.2720 - precision_3: 0.8838 - recall_3: 0.8838 - lr: 0.0006079162703827024
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8833 - loss: 0.2725 - precision_3: 0.8833 - recall_3: 0.8833 - val_accuracy: 0.7570 - val_loss: 0.8623 - val_precision_3: 0.7570 - val_recall_3: 0.7570
# Epoch 131/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8884 - loss: 0.2744 - precision_3: 0.8884 - recall_3: 0.8884 - lr: 0.0006028403877280653
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8885 - loss: 0.2744 - precision_3: 0.8885 - recall_3: 0.8885 - val_accuracy: 0.7729 - val_loss: 0.8625 - val_precision_3: 0.7729 - val_recall_3: 0.7729
# Epoch 132/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8709 - loss: 0.2902 - precision_3: 0.8709 - recall_3: 0.8709 - lr: 0.0005977537366561592
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8712 - loss: 0.2900 - precision_3: 0.8712 - recall_3: 0.8712 - val_accuracy: 0.7629 - val_loss: 0.8885 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 133/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8859 - loss: 0.2852 - precision_3: 0.8859 - recall_3: 0.8859 - lr: 0.0005926569574512541
# ...
# Epoch 257/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8910 - loss: 0.2495 - precision_3: 0.8910 - recall_3: 0.8910 - lr: 5.9342193708289415e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8912 - loss: 0.2494 - precision_3: 0.8912 - recall_3: 0.8912 - val_accuracy: 0.7410 - val_loss: 0.9842 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 258/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8995 - loss: 0.2388 - precision_3: 0.8995 - recall_3: 0.8995 - lr: 5.711058111046441e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8994 - loss: 0.2392 - precision_3: 0.8994 - recall_3: 0.8994 - val_accuracy: 0.7470 - val_loss: 0.9953 - val_precision_3: 0.7470 - val_recall_3: 0.7470
# Epoch 259/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8934 - loss: 0.2502 - precision_3: 0.8934 - recall_3: 0.8934 - lr: 5.492811760632321e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8934 - loss: 0.2499 - precision_3: 0.8934 - recall_3: 0.8934 - val_accuracy: 0.7490 - val_loss: 0.9659 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 260/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9000 - loss: 0.2370 - precision_3: 0.9000 - recall_3: 0.9000 - lr: 5.2794988732784986e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8999 - loss: 0.2374 - precision_3: 0.8999 - recall_3: 0.8999 - val_accuracy: 0.7430 - val_loss: 0.9800 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 261/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8900 - loss: 0.2504 - precision_3: 0.8900 - recall_3: 0.8900 - lr: 5.0711416406556964e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8900 - loss: 0.2505 - precision_3: 0.8900 - recall_3: 0.8900 - val_accuracy: 0.7371 - val_loss: 1.0067 - val_precision_3: 0.7371 - val_recall_3: 0.7371
# Epoch 262/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8956 - loss: 0.2440 - precision_3: 0.8956 - recall_3: 0.8956 - lr: 4.867775351158343e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8958 - loss: 0.2436 - precision_3: 0.8958 - recall_3: 0.8958 - val_accuracy: 0.7410 - val_loss: 0.9996 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 263/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8899 - loss: 0.2584 - precision_3: 0.8899 - recall_3: 0.8899 - lr: 4.6694058255525306e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8898 - loss: 0.2583 - precision_3: 0.8898 - recall_3: 0.8898 - val_accuracy: 0.7430 - val_loss: 0.9814 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 264/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9013 - loss: 0.2406 - precision_3: 0.9013 - recall_3: 0.9013 - lr: 4.476061076275073e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9010 - loss: 0.2407 - precision_3: 0.9010 - recall_3: 0.9010 - val_accuracy: 0.7410 - val_loss: 0.9864 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 265/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9008 - loss: 0.2349 - precision_3: 0.9008 - recall_3: 0.9008 - lr: 4.287767660571262e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9005 - loss: 0.2355 - precision_3: 0.9005 - recall_3: 0.9005 - val_accuracy: 0.7390 - val_loss: 1.0191 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 266/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8945 - loss: 0.2457 - precision_3: 0.8945 - recall_3: 0.8945 - lr: 4.104539766558446e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8949 - loss: 0.2453 - precision_3: 0.8949 - recall_3: 0.8949 - val_accuracy: 0.7390 - val_loss: 1.0223 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 267/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9067 - loss: 0.2342 - precision_3: 0.9067 - recall_3: 0.9067 - lr: 3.926401768694632e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9062 - loss: 0.2349 - precision_3: 0.9062 - recall_3: 0.9062 - val_accuracy: 0.7430 - val_loss: 1.0258 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 268/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8937 - loss: 0.2459 - precision_3: 0.8937 - recall_3: 0.8937 - lr: 3.753367855097167e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8939 - loss: 0.2456 - precision_3: 0.8939 - recall_3: 0.8939 - val_accuracy: 0.7410 - val_loss: 1.0292 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 269/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9086 - loss: 0.2244 - precision_3: 0.9086 - recall_3: 0.9086 - lr: 3.5854616726282984e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9081 - loss: 0.2252 - precision_3: 0.9081 - recall_3: 0.9081 - val_accuracy: 0.7390 - val_loss: 1.0214 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 270/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9076 - loss: 0.2240 - precision_3: 0.9076 - recall_3: 0.9076 - lr: 3.4227043215651065e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9069 - loss: 0.2253 - precision_3: 0.9069 - recall_3: 0.9069 - val_accuracy: 0.7390 - val_loss: 1.0206 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 271/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9055 - loss: 0.2365 - precision_3: 0.9055 - recall_3: 0.9055 - lr: 3.265104169258848e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9053 - loss: 0.2370 - precision_3: 0.9053 - recall_3: 0.9053 - val_accuracy: 0.7390 - val_loss: 1.0202 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 272/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8941 - loss: 0.2347 - precision_3: 0.8941 - recall_3: 0.8941 - lr: 3.112681952188723e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8939 - loss: 0.2353 - precision_3: 0.8939 - recall_3: 0.8939 - val_accuracy: 0.7390 - val_loss: 1.0046 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 273/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8905 - loss: 0.2456 - precision_3: 0.8905 - recall_3: 0.8905 - lr: 2.965458588732872e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8910 - loss: 0.2454 - precision_3: 0.8910 - recall_3: 0.8910 - val_accuracy: 0.7390 - val_loss: 1.0059 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 274/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8970 - loss: 0.2446 - precision_3: 0.8970 - recall_3: 0.8970 - lr: 2.8234513592906296e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8973 - loss: 0.2442 - precision_3: 0.8973 - recall_3: 0.8973 - val_accuracy: 0.7410 - val_loss: 0.9945 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 275/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9027 - loss: 0.2395 - precision_3: 0.9027 - recall_3: 0.9027 - lr: 2.686669358809013e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9027 - loss: 0.2395 - precision_3: 0.9027 - recall_3: 0.9027 - val_accuracy: 0.7410 - val_loss: 1.0003 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 276/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9017 - loss: 0.2333 - precision_3: 0.9017 - recall_3: 0.9017 - lr: 2.555130595283117e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9011 - loss: 0.2342 - precision_3: 0.9011 - recall_3: 0.9011 - val_accuracy: 0.7390 - val_loss: 1.0168 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 277/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9026 - loss: 0.2492 - precision_3: 0.9026 - recall_3: 0.9026 - lr: 2.4288521672133356e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9024 - loss: 0.2488 - precision_3: 0.9024 - recall_3: 0.9024 - val_accuracy: 0.7390 - val_loss: 1.0082 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 278/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8897 - loss: 0.2500 - precision_3: 0.8897 - recall_3: 0.8897 - lr: 2.307843169546686e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8902 - loss: 0.2501 - precision_3: 0.8902 - recall_3: 0.8902 - val_accuracy: 0.7410 - val_loss: 1.0232 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 279/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8986 - loss: 0.2382 - precision_3: 0.8986 - recall_3: 0.8986 - lr: 2.192121246480383e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8989 - loss: 0.2380 - precision_3: 0.8989 - recall_3: 0.8989 - val_accuracy: 0.7410 - val_loss: 1.0162 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 280/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8993 - loss: 0.2473 - precision_3: 0.8993 - recall_3: 0.8993 - lr: 2.0816927644773386e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8994 - loss: 0.2469 - precision_3: 0.8994 - recall_3: 0.8994 - val_accuracy: 0.7390 - val_loss: 1.0125 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 281/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8940 - loss: 0.2294 - precision_3: 0.8940 - recall_3: 0.8940 - lr: 1.976574640139006e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8939 - loss: 0.2301 - precision_3: 0.8939 - recall_3: 0.8939 - val_accuracy: 0.7390 - val_loss: 1.0126 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 282/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8941 - loss: 0.2470 - precision_3: 0.8941 - recall_3: 0.8941 - lr: 1.8767823348753154e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8942 - loss: 0.2470 - precision_3: 0.8942 - recall_3: 0.8942 - val_accuracy: 0.7390 - val_loss: 1.0166 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 283/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9032 - loss: 0.2208 - precision_3: 0.9032 - recall_3: 0.9032 - lr: 1.7823153029894456e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9028 - loss: 0.2217 - precision_3: 0.9028 - recall_3: 0.9028 - val_accuracy: 0.7390 - val_loss: 1.0213 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 284/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9068 - loss: 0.2303 - precision_3: 0.9068 - recall_3: 0.9068 - lr: 1.6931975551415235e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9061 - loss: 0.2310 - precision_3: 0.9061 - recall_3: 0.9061 - val_accuracy: 0.7371 - val_loss: 1.0204 - val_precision_3: 0.7371 - val_recall_3: 0.7371
# Epoch 285/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9015 - loss: 0.2412 - precision_3: 0.9015 - recall_3: 0.9015 - lr: 1.609425999049563e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9014 - loss: 0.2411 - precision_3: 0.9014 - recall_3: 0.9014 - val_accuracy: 0.7390 - val_loss: 1.0219 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 286/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8907 - loss: 0.2453 - precision_3: 0.8907 - recall_3: 0.8907 - lr: 1.5310184608097188e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8912 - loss: 0.2448 - precision_3: 0.8912 - recall_3: 0.8912 - val_accuracy: 0.7410 - val_loss: 1.0178 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 287/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8955 - loss: 0.2425 - precision_3: 0.8955 - recall_3: 0.8955 - lr: 1.4579834896721877e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8955 - loss: 0.2422 - precision_3: 0.8955 - recall_3: 0.8955 - val_accuracy: 0.7390 - val_loss: 1.0193 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 288/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9058 - loss: 0.2249 - precision_3: 0.9058 - recall_3: 0.9058 - lr: 1.39032126753591e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9059 - loss: 0.2253 - precision_3: 0.9059 - recall_3: 0.9059 - val_accuracy: 0.7390 - val_loss: 1.0262 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 289/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8938 - loss: 0.2523 - precision_3: 0.8938 - recall_3: 0.8938 - lr: 1.3280465282150544e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8935 - loss: 0.2527 - precision_3: 0.8935 - recall_3: 0.8935 - val_accuracy: 0.7390 - val_loss: 1.0274 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 290/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9052 - loss: 0.2370 - precision_3: 0.9052 - recall_3: 0.9052 - lr: 1.2711651834251825e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9052 - loss: 0.2369 - precision_3: 0.9052 - recall_3: 0.9052 - val_accuracy: 0.7390 - val_loss: 1.0259 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 291/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8912 - loss: 0.2395 - precision_3: 0.8912 - recall_3: 0.8912 - lr: 1.21968023449881e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8914 - loss: 0.2394 - precision_3: 0.8914 - recall_3: 0.8914 - val_accuracy: 0.7390 - val_loss: 1.0312 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 292/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9012 - loss: 0.2331 - precision_3: 0.9012 - recall_3: 0.9012 - lr: 1.1736033229681198e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9011 - loss: 0.2335 - precision_3: 0.9011 - recall_3: 0.9011 - val_accuracy: 0.7390 - val_loss: 1.0292 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 293/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9105 - loss: 0.2293 - precision_3: 0.9105 - recall_3: 0.9105 - lr: 1.1329316293995362e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9099 - loss: 0.2302 - precision_3: 0.9099 - recall_3: 0.9099 - val_accuracy: 0.7390 - val_loss: 1.0262 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 294/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8963 - loss: 0.2420 - precision_3: 0.8963 - recall_3: 0.8963 - lr: 1.0976769772241823e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8965 - loss: 0.2421 - precision_3: 0.8965 - recall_3: 0.8965 - val_accuracy: 0.7390 - val_loss: 1.0217 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 295/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8986 - loss: 0.2347 - precision_3: 0.8986 - recall_3: 0.8986 - lr: 1.0678363651095424e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8988 - loss: 0.2347 - precision_3: 0.8988 - recall_3: 0.8988 - val_accuracy: 0.7390 - val_loss: 1.0254 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 296/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9013 - loss: 0.2538 - precision_3: 0.9013 - recall_3: 0.9013 - lr: 1.0434185242047533e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9013 - loss: 0.2535 - precision_3: 0.9013 - recall_3: 0.9013 - val_accuracy: 0.7390 - val_loss: 1.0243 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 297/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8982 - loss: 0.2387 - precision_3: 0.8982 - recall_3: 0.8982 - lr: 1.0244266377412714e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8980 - loss: 0.2392 - precision_3: 0.8980 - recall_3: 0.8980 - val_accuracy: 0.7390 - val_loss: 1.0247 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 298/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8998 - loss: 0.2492 - precision_3: 0.8998 - recall_3: 0.8998 - lr: 1.0108547030540649e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8997 - loss: 0.2488 - precision_3: 0.8997 - recall_3: 0.8997 - val_accuracy: 0.7390 - val_loss: 1.0244 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 299/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9029 - loss: 0.2395 - precision_3: 0.9029 - recall_3: 0.9029 - lr: 1.0027144526247866e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9028 - loss: 0.2395 - precision_3: 0.9028 - recall_3: 0.9028 - val_accuracy: 0.7390 - val_loss: 1.0254 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 300/300
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8964 - loss: 0.2687 - precision_3: 0.8964 - recall_3: 0.8964 - lr: 1.0000000656873453e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8966 - loss: 0.2677 - precision_3: 0.8966 - recall_3: 0.8966 - val_accuracy: 0.7390 - val_loss: 1.0216 - val_precision_3: 0.7390 - val_recall_3: 0.7390

# %%
fig, axs = plt.subplots(2,1, figsize=(6, 10))
    
# Subplot 1: Plot training & validation accuracy values
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy ' + model_name)

axs[0].axhline(y=max(history.history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.93, f'Max Acc: {max(history.history["accuracy"])}', color='b')  # Add text annotation with the max value

axs[0].axhline(y=max(history.history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.83, f'Max Val Acc: {max(history.history["val_accuracy"])}', color='red')  # Add text annotation with the max value
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend(['Train', 'Val'], loc='upper left')
axs[0].set_ylim(0.5, 1)

# Subplot 2: Plot training & validation loss values
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss ' + model_name)
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['Train', 'Val'], loc='upper left')
axs[1].set_ylim(0, 1)

axs[1].axhline(y=min(history.history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.45, f'Min Val loss: {min(history.history["val_loss"])}', color='red')  # Add text annotation with the max value

axs[1].axhline(y=min(history.history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.1, f'Min loss: {min(history.history["loss"])}', color='b')  # Add text annotation with the max value

# Save the figure with subplots
plt.savefig(f'{plot_folder}\\ACC_LOSS_{model_name}.png')

# Show the plot
plt.show()

# %%
#import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical

# Assuming y_val is one-hot encoded, convert it back to class labels
y_true_classes = np.argmax(val_labels_categorical, axis=1)

# Make predictions on the validation set
y_pred = model.predict(val_data)

# Convert predictions from sigmoid output to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
cmap = plt.cm.Blues
plt.imshow(cm, interpolation='nearest', cmap=cmap)
plt.title('Confusion Matrix ' + model_name)
plt.colorbar()
tick_marks = np.arange(len(np.unique(y_true_classes)))  # this adapts to the number of classes dynamically
plt.xticks(tick_marks, tick_marks)
plt.yticks(tick_marks, tick_marks)

# Labeling the axes
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations inside the squares
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.savefig(f'{plot_folder}\\CM_{model_name}.png')

plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
mm.save_model(model, model_folder, model_name)
# Out:
# Model saved to .\MODELS_2000\M_1_2000.keras

# %%
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
print('training time:', (training_time/60), 'minutes')
# Convert the history object to a dictionary
history_dict = history.history

# Add the training time to the dictionary
history_dict['training_time'] = training_time
history_dict['training_time'] = training_time
history_dict['model'] = model_name
history_dict['batch_size'] = batch_size
history_dict['epochs'] = epochs
history_dict['learning_rate'] = initial_learning_rate
history_dict['decay_steps'] = decay_steps
history_dict['alpha'] = alpha
history_dict['loss_function'] = 'binary_crossentropy'
history_dict['optimizer'] = 'Adam'


# Save the dictionary to a JSON file

mm.save_history(history_dict, model_folder, model_name)
# Out:
# Training time: 337.08663177490234 seconds
# training time: 5.618110529581705 minutes
# History saved to .\MODELS_2000\M_1_2000_history.json

# %%
print('output shape')
print(y_pred.shape)
print('output')
print(y_pred)
# Out:
# output shape
# (502, 2)
# output
# [[4.4022585e-04 9.9955970e-01]
#  [5.3946169e-05 9.9994600e-01]
#  [5.6017463e-10 1.0000000e+00]
#  ...
#  [9.9721152e-01 2.7884992e-03]
#  [1.9331412e-01 8.0668586e-01]
#  [9.9916673e-01 8.3326036e-04]]

# %% [markdown]
# ## changing axis

# %%
models = ['M_1']

# %%
for model in models:
    #m = tf.keras.models.load_model(f'.\\MODELS\\{model}.keras')
    m = mm.load_model(model_folder, model)
    history = mm.load_history(model_folder, model)
    fig, axs = plt.subplots(2,1, figsize=(6, 10))
        
    # Subplot 1: Plot training & validation accuracy values
    axs[0].plot(history['accuracy'])
    axs[0].plot(history['val_accuracy'])
    axs[0].set_title('Model Accuracy ' + model)

    axs[0].axhline(y=max(history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.93, f'Max Acc: {max(history["accuracy"])}', color='b')  # Add text annotation with the max value

    axs[0].axhline(y=max(history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.83, f'Max Val Acc: {max(history["val_accuracy"])}', color='red')  # Add text annotation with the max value
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Val'], loc='upper left')
    axs[0].set_ylim(0.5, 1)

    # Subplot 2: Plot training & validation loss values
    axs[1].plot(history['loss'])
    axs[1].plot(history['val_loss'])
    axs[1].set_title('Model Loss ' + model)
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Val'], loc='upper left')
    axs[1].set_ylim(0, 1)

    axs[1].axhline(y=min(history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.45, f'Min Val loss: {min(history["val_loss"])}', color='red')  # Add text annotation with the max value

    axs[1].axhline(y=min(history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.1, f'Min loss: {min(history["loss"])}', color='b')  # Add text annotation with the max value

    # Save the figure with subplots
    plt.savefig(f'{plot_folder}\\ACC_LOSS_{model}.png')

    # Show the plot
    plt.show()
# Out:
# Loading model from .\MODELS_2000\M_1.keras
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 for model in models:
#       2     #m = tf.keras.models.load_model(f'.\\MODELS\\{model}.keras')
# ----> 3     m = mm.load_model(model_folder, model)
#       4     history = mm.load_history(model_folder, model)
#       5     fig, axs = plt.subplots(2,1, figsize=(6, 10))
#
# File c:\Users\al385931\OneDrive - Universitat Jaume I\TFM\TFM_NEW\SECOND_CUT\movmus.py:143, in load_model(model_folder, model_name)
#     140 def load_model(model_folder, model_name):
#     141     print(f"Loading model from {model_folder}\\{model_name}.keras")
# --> 143     m = tf.keras.models.load_model(f'{model_folder}\\{model_name}.keras')
#     144     check_model_layers(m)
#     145     return m
#
# File c:\Users\al385931\AppData\Local\anaconda3\envs\tfm2\Lib\site-packages\keras\src\saving\saving_api.py:198, in load_model(filepath, custom_objects, compile, safe_mode)
#     194     return legacy_h5_format.load_model_from_hdf5(
#     195         filepath, custom_objects=custom_objects, compile=compile
#     196     )
#     197 elif str(filepath).endswith(".keras"):
# --> 198     raise ValueError(
#     199         f"File not found: filepath={filepath}. "
#     200         "Please ensure the file is an accessible `.keras` "
#     201         "zip file."
#     202     )
#     203 else:
#     204     raise ValueError(
#     205         f"File format not supported: filepath={filepath}. "
#     206         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     215         "might have a different name)."
#     216     )
#
# ValueError: File not found: filepath=.\MODELS_2000\M_1.keras. Please ensure the file is an accessible `.keras` zip file.
