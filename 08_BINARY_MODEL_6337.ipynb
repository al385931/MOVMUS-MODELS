# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, MaxPooling1D, GlobalAveragePooling1D, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import compute_class_weight
from sklearn.utils import class_weight
from tensorflow.keras.metrics import Precision, Recall, AUC, SparseCategoricalAccuracy
import time


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import movmus as mm
import movmus2 as mm2

import json

# %% [markdown]
# ## LOADING DATA

# %%
train_data, val_data, test_data = mm.load_data_npz('EMG_6337_data.npz')
# Out:
# shape of training data: (2720, 6337, 7)
# shape of validation data: (502, 6337, 7)
# shape of test data: (661, 6337, 7)

# %%
train_labels = mm.load_labels('training_labels.npz')
val_labels = mm.load_labels('validation_labels.npz')
test_labels = mm.load_labels('test_labels.npz')
print('train labels:', train_labels.shape, 'val labels:', val_labels.shape, 'test labels:', test_labels.shape)
# Out:
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
train_labels.head()
# Out:
#     ID  GRASP_DH
# 0  1.0       1.0
# 1  2.0       1.0
# 2  3.0       1.0
# 3  4.0       1.0
# 4  5.0       1.0

# %%
train_labels_categorical = mm.adjust_labels(train_labels)
val_labels_categorical = mm.adjust_labels(val_labels)
test_labels_categorical = mm.adjust_labels(test_labels)
print('train labels:', train_labels_categorical.shape, 'val labels:', val_labels_categorical.shape, 'test labels:', test_labels_categorical.shape)
# Out:
# Labels after one-hot encoding: (2720, 2)
# Labels after one-hot encoding: (502, 2)
# Labels after one-hot encoding: (661, 2)
# train labels: (2720, 2) val labels: (502, 2) test labels: (661, 2)

# %%
print(train_labels_categorical)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
first_column = train_labels_categorical[:, 0]
#print(first_column)
second_column = train_labels_categorical[:, 1]
# Count the number of 0s
count_first = np.count_nonzero(first_column == 1)

# Calculate the percentage
percentage_first = (count_first / len(first_column)) * 100

print(f"Percentage of 1s in the first column: {percentage_first}%")

count_second = np.count_nonzero(second_column == 1)
percentage_second = (count_second / len(second_column)) * 100
print(f"Percentage of 1s in the second column: {percentage_second}%")
# Out:
# Percentage of 1s in the first column: 61.360294117647065%
# Percentage of 1s in the second column: 38.63970588235294%

# %% [markdown]
# ## MODEL CREATION

# %%
from tensorflow.keras.regularizers import l2

# %%
model_name = 'M_1_6337'
model_folder = '.\\MODELS_6337'
plot_folder = '.\\PLOTS_6337'

# %%
num_samples = len(train_data)  # Number of training samples
print("Number of training samples:", num_samples)
possible_batch_sizes = [i for i in range(1, num_samples + 1) if num_samples % i == 0]

print("Possible batch sizes that divide evenly:", possible_batch_sizes)
# Out:
# Number of training samples: 2720
# Possible batch sizes that divide evenly: [1, 2, 4, 5, 8, 10, 16, 17, 20, 32, 34, 40, 68, 80, 85, 136, 160, 170, 272, 340, 544, 680, 1360, 2720]

# %%
batch_size = 85
epochs = 300

# %%
# Define the learning rate schedule
initial_learning_rate = 0.001
decay_steps = (num_samples/batch_size)*epochs  # 2752 samples/ 86 bs = 32 --> 32 * 250 epochs = 8000 steps
print("Decay steps:", decay_steps)
alpha = 0.01 

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    alpha=alpha
)
# Out:
# Decay steps: 9600.0

# %%
from tensorflow.keras.callbacks import Callback

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = tf.keras.backend.get_value(self.model.optimizer.learning_rate)
        print(f" - lr: {lr}")

# %%
model = Sequential([
    # Layer 1
    tf.keras.layers.Conv1D(filters=16, kernel_size=10, padding='valid', activation='relu', input_shape=(6337, 7)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    # Layer 2
    tf.keras.layers.Conv1D(filters=32, kernel_size=10, padding='valid', activation='relu'),
    BatchNormalization(),
    GlobalAveragePooling1D(),
    Dropout(0.2),

    # Layer 3
    tf.keras.layers.Dense(32, activation='relu'),

    # Exit layer
    tf.keras.layers.Dense(2, activation='softmax')
])
# Out:
# c:\Users\al385931\AppData\Local\anaconda3\envs\tfm2\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=lr_schedule),
    metrics=['accuracy', Precision(), Recall()] 
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 6328, 16)       │         1,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6328, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 3164, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 3155, 32)       │         5,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3155, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_3      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,602 (29.70 KB)
#  Trainable params: 7,506 (29.32 KB)
#  Non-trainable params: 96 (384.00 B)

# %% [markdown]
# ## TRAINING

# %%
tf.keras.config.disable_traceback_filtering()

# %%
start_time = time.time()

# Train the model
history = model.fit(
    train_data, train_labels_categorical,
    validation_data=(val_data, val_labels_categorical),
    epochs=epochs,  
    batch_size=batch_size,
    callbacks=[LearningRateLogger()],  
    verbose=1)
    #class_weight = class_weight_dict
#)

end_time = time.time()
# Out:
# Epoch 1/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6494 - loss: 0.6564 - precision_3: 0.6494 - recall_3: 0.6494 - lr: 0.0009999729227274656
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.6515 - loss: 0.6553 - precision_3: 0.6515 - recall_3: 0.6515 - val_accuracy: 0.5339 - val_loss: 0.6906 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7823 - loss: 0.5290 - precision_3: 0.7823 - recall_3: 0.7823 - lr: 0.0009998914320021868
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.7823 - loss: 0.5284 - precision_3: 0.7823 - recall_3: 0.7823 - val_accuracy: 0.5339 - val_loss: 0.7266 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7810 - loss: 0.4884 - precision_3: 0.7810 - recall_3: 0.7810 - lr: 0.0009997556917369366
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.7814 - loss: 0.4879 - precision_3: 0.7814 - recall_3: 0.7814 - val_accuracy: 0.5339 - val_loss: 0.7815 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7958 - loss: 0.4584 - precision_3: 0.7958 - recall_3: 0.7958 - lr: 0.0009995659347623587
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7957 - loss: 0.4585 - precision_3: 0.7957 - recall_3: 0.7957 - val_accuracy: 0.5339 - val_loss: 0.7817 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7947 - loss: 0.4448 - precision_3: 0.7947 - recall_3: 0.7947 - lr: 0.0009993216954171658
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.7947 - loss: 0.4450 - precision_3: 0.7947 - recall_3: 0.7947 - val_accuracy: 0.5339 - val_loss: 0.7830 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7934 - loss: 0.4419 - precision_3: 0.7934 - recall_3: 0.7934 - lr: 0.0009990233229473233
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7935 - loss: 0.4419 - precision_3: 0.7935 - recall_3: 0.7935 - val_accuracy: 0.5339 - val_loss: 0.8048 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8023 - loss: 0.4364 - precision_3: 0.8023 - recall_3: 0.8023 - lr: 0.0009986707009375095
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8023 - loss: 0.4363 - precision_3: 0.8023 - recall_3: 0.8023 - val_accuracy: 0.5339 - val_loss: 0.8516 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8124 - loss: 0.4256 - precision_3: 0.8124 - recall_3: 0.8124 - lr: 0.0009982639458030462
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8124 - loss: 0.4255 - precision_3: 0.8124 - recall_3: 0.8124 - val_accuracy: 0.5339 - val_loss: 0.8226 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8135 - loss: 0.4156 - precision_3: 0.8135 - recall_3: 0.8135 - lr: 0.0009978031739592552
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8134 - loss: 0.4156 - precision_3: 0.8134 - recall_3: 0.8134 - val_accuracy: 0.5339 - val_loss: 0.8684 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8339 - loss: 0.3955 - precision_3: 0.8339 - recall_3: 0.8339 - lr: 0.0009972883854061365
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8334 - loss: 0.3961 - precision_3: 0.8334 - recall_3: 0.8334 - val_accuracy: 0.5339 - val_loss: 0.7889 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8290 - loss: 0.4071 - precision_3: 0.8290 - recall_3: 0.8290 - lr: 0.0009967195801436901
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8288 - loss: 0.4072 - precision_3: 0.8288 - recall_3: 0.8288 - val_accuracy: 0.5339 - val_loss: 0.8501 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8137 - loss: 0.4117 - precision_3: 0.8137 - recall_3: 0.8137 - lr: 0.0009960968745872378
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8138 - loss: 0.4115 - precision_3: 0.8138 - recall_3: 0.8138 - val_accuracy: 0.5339 - val_loss: 0.8721 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8269 - loss: 0.4020 - precision_3: 0.8269 - recall_3: 0.8269 - lr: 0.0009954202687367797
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8269 - loss: 0.4019 - precision_3: 0.8269 - recall_3: 0.8269 - val_accuracy: 0.5339 - val_loss: 0.9708 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8205 - loss: 0.4090 - precision_3: 0.8205 - recall_3: 0.8205 - lr: 0.0009946898790076375
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8205 - loss: 0.4090 - precision_3: 0.8205 - recall_3: 0.8205 - val_accuracy: 0.5339 - val_loss: 1.0713 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8362 - loss: 0.3759 - precision_3: 0.8362 - recall_3: 0.8362 - lr: 0.000993905821815133
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8361 - loss: 0.3762 - precision_3: 0.8361 - recall_3: 0.8361 - val_accuracy: 0.5339 - val_loss: 0.9840 - val_precision_3: 0.5339 - val_recall_3: 0.5339
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8173 - loss: 0.4037 - precision_3: 0.8173 - recall_3: 0.8173 - lr: 0.0009930680971592665
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8176 - loss: 0.4034 - precision_3: 0.8176 - recall_3: 0.8176 - val_accuracy: 0.5359 - val_loss: 1.1183 - val_precision_3: 0.5359 - val_recall_3: 0.5359
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8347 - loss: 0.3772 - precision_3: 0.8347 - recall_3: 0.8347 - lr: 0.0009921768214553595
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8343 - loss: 0.3778 - precision_3: 0.8343 - recall_3: 0.8343 - val_accuracy: 0.5378 - val_loss: 1.0258 - val_precision_3: 0.5378 - val_recall_3: 0.5378
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8363 - loss: 0.3743 - precision_3: 0.8363 - recall_3: 0.8363 - lr: 0.0009912322275340557
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.8361 - loss: 0.3746 - precision_3: 0.8361 - recall_3: 0.8361 - val_accuracy: 0.5458 - val_loss: 0.9985 - val_precision_3: 0.5458 - val_recall_3: 0.5458
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8377 - loss: 0.3821 - precision_3: 0.8377 - recall_3: 0.8377 - lr: 0.0009902341989800334
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8374 - loss: 0.3823 - precision_3: 0.8374 - recall_3: 0.8374 - val_accuracy: 0.5797 - val_loss: 0.9371 - val_precision_3: 0.5797 - val_recall_3: 0.5797
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8431 - loss: 0.3735 - precision_3: 0.8431 - recall_3: 0.8431 - lr: 0.000989183085039258
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8430 - loss: 0.3736 - precision_3: 0.8430 - recall_3: 0.8430 - val_accuracy: 0.6514 - val_loss: 0.6683 - val_precision_3: 0.6514 - val_recall_3: 0.6514
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8263 - loss: 0.3849 - precision_3: 0.8263 - recall_3: 0.8263 - lr: 0.0009880787692964077
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8265 - loss: 0.3849 - precision_3: 0.8265 - recall_3: 0.8265 - val_accuracy: 0.4861 - val_loss: 1.5278 - val_precision_3: 0.4861 - val_recall_3: 0.4861
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8387 - loss: 0.3668 - precision_3: 0.8387 - recall_3: 0.8387 - lr: 0.000986921600997448
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.8582 - loss: 0.3321 - precision_3: 0.8582 - recall_3: 0.8582 - val_accuracy: 0.6056 - val_loss: 1.0872 - val_precision_3: 0.6056 - val_recall_3: 0.6056
# Epoch 68/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8590 - loss: 0.3310 - precision_3: 0.8590 - recall_3: 0.8590 - lr: 0.0008797125774435699
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8590 - loss: 0.3310 - precision_3: 0.8590 - recall_3: 0.8590 - val_accuracy: 0.7709 - val_loss: 0.6766 - val_precision_3: 0.7709 - val_recall_3: 0.7709
# Epoch 69/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8615 - loss: 0.3247 - precision_3: 0.8615 - recall_3: 0.8615 - lr: 0.0008763050427660346
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8613 - loss: 0.3247 - precision_3: 0.8613 - recall_3: 0.8613 - val_accuracy: 0.7490 - val_loss: 0.6880 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 70/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8686 - loss: 0.3187 - precision_3: 0.8686 - recall_3: 0.8686 - lr: 0.000872856704518199
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8683 - loss: 0.3189 - precision_3: 0.8683 - recall_3: 0.8683 - val_accuracy: 0.6633 - val_loss: 0.9189 - val_precision_3: 0.6633 - val_recall_3: 0.6633
# Epoch 71/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8743 - loss: 0.3184 - precision_3: 0.8743 - recall_3: 0.8743 - lr: 0.0008693681447766721
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8741 - loss: 0.3183 - precision_3: 0.8741 - recall_3: 0.8741 - val_accuracy: 0.7629 - val_loss: 0.7291 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 72/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8688 - loss: 0.3144 - precision_3: 0.8688 - recall_3: 0.8688 - lr: 0.0008658395381644368
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8686 - loss: 0.3145 - precision_3: 0.8686 - recall_3: 0.8686 - val_accuracy: 0.7311 - val_loss: 0.6242 - val_precision_3: 0.7311 - val_recall_3: 0.7311
# Epoch 73/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8612 - loss: 0.3156 - precision_3: 0.8612 - recall_3: 0.8612 - lr: 0.0008622713503427804
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8612 - loss: 0.3158 - precision_3: 0.8612 - recall_3: 0.8612 - val_accuracy: 0.7112 - val_loss: 0.6602 - val_precision_3: 0.7112 - val_recall_3: 0.7112
# Epoch 74/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8731 - loss: 0.3028 - precision_3: 0.8731 - recall_3: 0.8731 - lr: 0.0008586639887653291
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8729 - loss: 0.3031 - precision_3: 0.8729 - recall_3: 0.8729 - val_accuracy: 0.7390 - val_loss: 0.6215 - val_precision_3: 0.7390 - val_recall_3: 0.7390
# Epoch 75/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8642 - loss: 0.3270 - precision_3: 0.8642 - recall_3: 0.8642 - lr: 0.0008550179190933704
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8642 - loss: 0.3270 - precision_3: 0.8642 - recall_3: 0.8642 - val_accuracy: 0.6733 - val_loss: 0.6878 - val_precision_3: 0.6733 - val_recall_3: 0.6733
# Epoch 76/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8638 - loss: 0.3337 - precision_3: 0.8638 - recall_3: 0.8638 - lr: 0.0008513334323652089
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8744 - loss: 0.2975 - precision_3: 0.8744 - recall_3: 0.8744 - val_accuracy: 0.7291 - val_loss: 0.7901 - val_precision_3: 0.7291 - val_recall_3: 0.7291
# Epoch 86/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8570 - loss: 0.3160 - precision_3: 0.8570 - recall_3: 0.8570 - lr: 0.0008124682353809476
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8571 - loss: 0.3159 - precision_3: 0.8571 - recall_3: 0.8571 - val_accuracy: 0.6195 - val_loss: 1.8053 - val_precision_3: 0.6195 - val_recall_3: 0.6195
# Epoch 87/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8653 - loss: 0.3090 - precision_3: 0.8653 - recall_3: 0.8653 - lr: 0.0008083890425041318
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8653 - loss: 0.3091 - precision_3: 0.8653 - recall_3: 0.8653 - val_accuracy: 0.6335 - val_loss: 1.1907 - val_precision_3: 0.6335 - val_recall_3: 0.6335
# Epoch 88/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8636 - loss: 0.3164 - precision_3: 0.8636 - recall_3: 0.8636 - lr: 0.0008042766130529344
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8636 - loss: 0.3165 - precision_3: 0.8636 - recall_3: 0.8636 - val_accuracy: 0.7191 - val_loss: 1.0124 - val_precision_3: 0.7191 - val_recall_3: 0.7191
# Epoch 89/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8604 - loss: 0.3159 - precision_3: 0.8604 - recall_3: 0.8604 - lr: 0.0008001312962733209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8605 - loss: 0.3158 - precision_3: 0.8605 - recall_3: 0.8605 - val_accuracy: 0.7610 - val_loss: 0.7630 - val_precision_3: 0.7610 - val_recall_3: 0.7610
# Epoch 90/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8544 - loss: 0.3226 - precision_3: 0.8544 - recall_3: 0.8544 - lr: 0.0007959537324495614
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8547 - loss: 0.3221 - precision_3: 0.8547 - recall_3: 0.8547 - val_accuracy: 0.7829 - val_loss: 0.7709 - val_precision_3: 0.7829 - val_recall_3: 0.7829
# Epoch 91/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8675 - loss: 0.3105 - precision_3: 0.8675 - recall_3: 0.8675 - lr: 0.0007917441544122994
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8675 - loss: 0.3104 - precision_3: 0.8675 - recall_3: 0.8675 - val_accuracy: 0.7629 - val_loss: 0.6753 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 92/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8654 - loss: 0.3165 - precision_3: 0.8654 - recall_3: 0.8654 - lr: 0.0007875032024458051
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8656 - loss: 0.3161 - precision_3: 0.8656 - recall_3: 0.8656 - val_accuracy: 0.7530 - val_loss: 0.5996 - val_precision_3: 0.7530 - val_recall_3: 0.7530
# Epoch 93/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8654 - loss: 0.3135 - precision_3: 0.8654 - recall_3: 0.8654 - lr: 0.0007832312840037048
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8653 - loss: 0.3134 - precision_3: 0.8653 - recall_3: 0.8653 - val_accuracy: 0.7649 - val_loss: 0.6688 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 94/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8679 - loss: 0.3114 - precision_3: 0.8679 - recall_3: 0.8679 - lr: 0.0007789288647472858
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8680 - loss: 0.3110 - precision_3: 0.8680 - recall_3: 0.8680 - val_accuracy: 0.7410 - val_loss: 0.7730 - val_precision_3: 0.7410 - val_recall_3: 0.7410
# Epoch 95/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8691 - loss: 0.3096 - precision_3: 0.8691 - recall_3: 0.8691 - lr: 0.0007745962939225137
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8691 - loss: 0.3095 - precision_3: 0.8691 - recall_3: 0.8691 - val_accuracy: 0.7590 - val_loss: 0.7804 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 96/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8626 - loss: 0.3132 - precision_3: 0.8626 - recall_3: 0.8626 - lr: 0.0007702342700213194
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8627 - loss: 0.3131 - precision_3: 0.8627 - recall_3: 0.8627 - val_accuracy: 0.7689 - val_loss: 0.7514 - val_precision_3: 0.7689 - val_recall_3: 0.7689
# Epoch 97/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8837 - loss: 0.2837 - precision_3: 0.8837 - recall_3: 0.8837 - lr: 0.0007658432004973292
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8834 - loss: 0.2840 - precision_3: 0.8834 - recall_3: 0.8834 - val_accuracy: 0.7231 - val_loss: 0.8967 - val_precision_3: 0.7231 - val_recall_3: 0.7231
# Epoch 98/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8757 - loss: 0.2876 - precision_3: 0.8757 - recall_3: 0.8757 - lr: 0.0007614234345965087
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8755 - loss: 0.2880 - precision_3: 0.8755 - recall_3: 0.8755 - val_accuracy: 0.7251 - val_loss: 0.9199 - val_precision_3: 0.7251 - val_recall_3: 0.7251
# Epoch 99/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8699 - loss: 0.3118 - precision_3: 0.8699 - recall_3: 0.8699 - lr: 0.0007569754961878061
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8699 - loss: 0.3116 - precision_3: 0.8699 - recall_3: 0.8699 - val_accuracy: 0.7351 - val_loss: 0.8022 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 100/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8714 - loss: 0.2955 - precision_3: 0.8714 - recall_3: 0.8714 - lr: 0.0007525000255554914
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8713 - loss: 0.2959 - precision_3: 0.8713 - recall_3: 0.8713 - val_accuracy: 0.7430 - val_loss: 0.7196 - val_precision_3: 0.7430 - val_recall_3: 0.7430
# Epoch 101/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8787 - loss: 0.2838 - precision_3: 0.8787 - recall_3: 0.8787 - lr: 0.0007479973719455302
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8785 - loss: 0.2844 - precision_3: 0.8785 - recall_3: 0.8785 - val_accuracy: 0.7590 - val_loss: 0.7689 - val_precision_3: 0.7590 - val_recall_3: 0.7590
# Epoch 102/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8667 - loss: 0.3023 - precision_3: 0.8667 - recall_3: 0.8667 - lr: 0.0007434680592268705
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8668 - loss: 0.3022 - precision_3: 0.8668 - recall_3: 0.8668 - val_accuracy: 0.7709 - val_loss: 0.7913 - val_precision_3: 0.7709 - val_recall_3: 0.7709
# Epoch 103/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8716 - loss: 0.2873 - precision_3: 0.8716 - recall_3: 0.8716 - lr: 0.0007389126694761217
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8677 - loss: 0.2970 - precision_3: 0.8677 - recall_3: 0.8677 - val_accuracy: 0.7351 - val_loss: 0.8025 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 113/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8816 - loss: 0.2799 - precision_3: 0.8816 - recall_3: 0.8816 - lr: 0.0006920311716385186
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8815 - loss: 0.2802 - precision_3: 0.8815 - recall_3: 0.8815 - val_accuracy: 0.7629 - val_loss: 0.6755 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 114/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8724 - loss: 0.3039 - precision_3: 0.8724 - recall_3: 0.8724 - lr: 0.0006872217054478824
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.8724 - loss: 0.3036 - precision_3: 0.8724 - recall_3: 0.8724 - val_accuracy: 0.7649 - val_loss: 0.6377 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 115/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8734 - loss: 0.2939 - precision_3: 0.8734 - recall_3: 0.8734 - lr: 0.0006823921576142311
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8735 - loss: 0.2938 - precision_3: 0.8735 - recall_3: 0.8735 - val_accuracy: 0.7550 - val_loss: 0.6198 - val_precision_3: 0.7550 - val_recall_3: 0.7550
# Epoch 116/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8756 - loss: 0.2794 - precision_3: 0.8756 - recall_3: 0.8756 - lr: 0.0006775431684218347
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8754 - loss: 0.2797 - precision_3: 0.8754 - recall_3: 0.8754 - val_accuracy: 0.7351 - val_loss: 0.8111 - val_precision_3: 0.7351 - val_recall_3: 0.7351
# Epoch 117/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8803 - loss: 0.2736 - precision_3: 0.8803 - recall_3: 0.8803 - lr: 0.0006726753199473023
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8800 - loss: 0.2740 - precision_3: 0.8800 - recall_3: 0.8800 - val_accuracy: 0.7490 - val_loss: 0.6629 - val_precision_3: 0.7490 - val_recall_3: 0.7490
# Epoch 118/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8779 - loss: 0.2918 - precision_3: 0.8779 - recall_3: 0.8779 - lr: 0.0006677889614365995
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8779 - loss: 0.2917 - precision_3: 0.8779 - recall_3: 0.8779 - val_accuracy: 0.7649 - val_loss: 0.6057 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 119/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8739 - loss: 0.2747 - precision_3: 0.8739 - recall_3: 0.8739 - lr: 0.000662884849589318
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8738 - loss: 0.2754 - precision_3: 0.8738 - recall_3: 0.8738 - val_accuracy: 0.6733 - val_loss: 0.9247 - val_precision_3: 0.6733 - val_recall_3: 0.6733
# Epoch 120/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8793 - loss: 0.2802 - precision_3: 0.8793 - recall_3: 0.8793 - lr: 0.0006579634500667453
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8789 - loss: 0.2808 - precision_3: 0.8789 - recall_3: 0.8789 - val_accuracy: 0.7092 - val_loss: 0.8245 - val_precision_3: 0.7092 - val_recall_3: 0.7092
# Epoch 121/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8697 - loss: 0.2985 - precision_3: 0.8697 - recall_3: 0.8697 - lr: 0.0006530252285301685
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s
-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.8990 - loss: 0.2489 - precision_3: 0.8990 - recall_3: 0.8990 - val_accuracy: 0.7709 - val_loss: 0.8089 - val_precision_3: 0.7709 - val_recall_3: 0.7709
# Epoch 274/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8898 - loss: 0.2551 - precision_3: 0.8898 - recall_3: 0.8898 - lr: 2.8234513592906296e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8898 - loss: 0.2551 - precision_3: 0.8898 - recall_3: 0.8898 - val_accuracy: 0.7689 - val_loss: 0.8057 - val_precision_3: 0.7689 - val_recall_3: 0.7689
# Epoch 275/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8899 - loss: 0.2686 - precision_3: 0.8899 - recall_3: 0.8899 - lr: 2.686669358809013e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.8900 - loss: 0.2682 - precision_3: 0.8900 - recall_3: 0.8900 - val_accuracy: 0.7869 - val_loss: 0.7770 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 276/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9047 - loss: 0.2383 - precision_3: 0.9047 - recall_3: 0.9047 - lr: 2.555130595283117e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.9044 - loss: 0.2387 - precision_3: 0.9044 - recall_3: 0.9044 - val_accuracy: 0.7829 - val_loss: 0.7757 - val_precision_3: 0.7829 - val_recall_3: 0.7829
# Epoch 277/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9027 - loss: 0.2354 - precision_3: 0.9027 - recall_3: 0.9027 - lr: 2.4288521672133356e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9024 - loss: 0.2360 - precision_3: 0.9024 - recall_3: 0.9024 - val_accuracy: 0.7888 - val_loss: 0.7771 - val_precision_3: 0.7888 - val_recall_3: 0.7888
# Epoch 278/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8825 - loss: 0.2671 - precision_3: 0.8825 - recall_3: 0.8825 - lr: 2.307843169546686e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - accuracy: 0.8827 - loss: 0.2669 - precision_3: 0.8827 - recall_3: 0.8827 - val_accuracy: 0.7629 - val_loss: 0.8083 - val_precision_3: 0.7629 - val_recall_3: 0.7629
# Epoch 279/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8850 - loss: 0.2604 - precision_3: 0.8850 - recall_3: 0.8850 - lr: 2.192121246480383e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8853 - loss: 0.2601 - precision_3: 0.8853 - recall_3: 0.8853 - val_accuracy: 0.7908 - val_loss: 0.7775 - val_precision_3: 0.7908 - val_recall_3: 0.7908
# Epoch 280/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9057 - loss: 0.2287 - precision_3: 0.9057 - recall_3: 0.9057 - lr: 2.0816927644773386e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9054 - loss: 0.2294 - precision_3: 0.9054 - recall_3: 0.9054 - val_accuracy: 0.7789 - val_loss: 0.7861 - val_precision_3: 0.7789 - val_recall_3: 0.7789
# Epoch 281/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8923 - loss: 0.2448 - precision_3: 0.8923 - recall_3: 0.8923 - lr: 1.976574640139006e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.8921 - loss: 0.2452 - precision_3: 0.8921 - recall_3: 0.8921 - val_accuracy: 0.7709 - val_loss: 0.8013 - val_precision_3: 0.7709 - val_recall_3: 0.7709
# Epoch 282/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8933 - loss: 0.2610 - precision_3: 0.8933 - recall_3: 0.8933 - lr: 1.8767823348753154e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.8932 - loss: 0.2610 - precision_3: 0.8932 - recall_3: 0.8932 - val_accuracy: 0.7689 - val_loss: 0.7968 - val_precision_3: 0.7689 - val_recall_3: 0.7689
# Epoch 283/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8951 - loss: 0.2499 - precision_3: 0.8951 - recall_3: 0.8951 - lr: 1.7823153029894456e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.8949 - loss: 0.2501 - precision_3: 0.8949 - recall_3: 0.8949 - val_accuracy: 0.7649 - val_loss: 0.8082 - val_precision_3: 0.7649 - val_recall_3: 0.7649
# Epoch 284/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8933 - loss: 0.2521 - precision_3: 0.8933 - recall_3: 0.8933 - lr: 1.6931975551415235e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.8933 - loss: 0.2520 - precision_3: 0.8933 - recall_3: 0.8933 - val_accuracy: 0.7669 - val_loss: 0.8035 - val_precision_3: 0.7669 - val_recall_3: 0.7669
# Epoch 285/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8836 - loss: 0.2798 - precision_3: 0.8836 - recall_3: 0.8836 - lr: 1.609425999049563e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.8841 - loss: 0.2790 - precision_3: 0.8841 - recall_3: 0.8841 - val_accuracy: 0.7789 - val_loss: 0.7870 - val_precision_3: 0.7789 - val_recall_3: 0.7789
# Epoch 286/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8997 - loss: 0.2661 - precision_3: 0.8997 - recall_3: 0.8997 - lr: 1.5310184608097188e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8997 - loss: 0.2657 - precision_3: 0.8997 - recall_3: 0.8997 - val_accuracy: 0.7869 - val_loss: 0.7668 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 287/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8973 - loss: 0.2469 - precision_3: 0.8973 - recall_3: 0.8973 - lr: 1.4579834896721877e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.8972 - loss: 0.2472 - precision_3: 0.8972 - recall_3: 0.8972 - val_accuracy: 0.7869 - val_loss: 0.7716 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 288/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8869 - loss: 0.2644 - precision_3: 0.8869 - recall_3: 0.8869 - lr: 1.39032126753591e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8871 - loss: 0.2641 - precision_3: 0.8871 - recall_3: 0.8871 - val_accuracy: 0.7869 - val_loss: 0.7770 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 289/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8765 - loss: 0.2710 - precision_3: 0.8765 - recall_3: 0.8765 - lr: 1.3280465282150544e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.8769 - loss: 0.2704 - precision_3: 0.8769 - recall_3: 0.8769 - val_accuracy: 0.7869 - val_loss: 0.7666 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 290/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9125 - loss: 0.2343 - precision_3: 0.9125 - recall_3: 0.9125 - lr: 1.2711651834251825e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - accuracy: 0.9122 - loss: 0.2347 - precision_3: 0.9122 - recall_3: 0.9122 - val_accuracy: 0.7849 - val_loss: 0.7754 - val_precision_3: 0.7849 - val_recall_3: 0.7849
# Epoch 291/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8959 - loss: 0.2436 - precision_3: 0.8959 - recall_3: 0.8959 - lr: 1.21968023449881e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.8958 - loss: 0.2440 - precision_3: 0.8958 - recall_3: 0.8958 - val_accuracy: 0.7829 - val_loss: 0.7867 - val_precision_3: 0.7829 - val_recall_3: 0.7829
# Epoch 292/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8951 - loss: 0.2472 - precision_3: 0.8951 - recall_3: 0.8951 - lr: 1.1736033229681198e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.8950 - loss: 0.2472 - precision_3: 0.8950 - recall_3: 0.8950 - val_accuracy: 0.7809 - val_loss: 0.7895 - val_precision_3: 0.7809 - val_recall_3: 0.7809
# Epoch 293/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8863 - loss: 0.2576 - precision_3: 0.8863 - recall_3: 0.8863 - lr: 1.1329316293995362e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8864 - loss: 0.2577 - precision_3: 0.8864 - recall_3: 0.8864 - val_accuracy: 0.7869 - val_loss: 0.7793 - val_precision_3: 0.7869 - val_recall_3: 0.7869
# Epoch 294/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8938 - loss: 0.2519 - precision_3: 0.8938 - recall_3: 0.8938 - lr: 1.0976769772241823e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8938 - loss: 0.2522 - precision_3: 0.8938 - recall_3: 0.8938 - val_accuracy: 0.7888 - val_loss: 0.7734 - val_precision_3: 0.7888 - val_recall_3: 0.7888
# Epoch 295/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8942 - loss: 0.2513 - precision_3: 0.8942 - recall_3: 0.8942 - lr: 1.0678363651095424e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.8942 - loss: 0.2513 - precision_3: 0.8942 - recall_3: 0.8942 - val_accuracy: 0.7849 - val_loss: 0.7697 - val_precision_3: 0.7849 - val_recall_3: 0.7849
# Epoch 296/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8999 - loss: 0.2286 - precision_3: 0.8999 - recall_3: 0.8999 - lr: 1.0434185242047533e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.8996 - loss: 0.2293 - precision_3: 0.8996 - recall_3: 0.8996 - val_accuracy: 0.7849 - val_loss: 0.7712 - val_precision_3: 0.7849 - val_recall_3: 0.7849
# Epoch 297/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9001 - loss: 0.2419 - precision_3: 0.9001 - recall_3: 0.9001 - lr: 1.0244266377412714e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.8998 - loss: 0.2424 - precision_3: 0.8998 - recall_3: 0.8998 - val_accuracy: 0.7888 - val_loss: 0.7776 - val_precision_3: 0.7888 - val_recall_3: 0.7888
# Epoch 298/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8998 - loss: 0.2503 - precision_3: 0.8998 - recall_3: 0.8998 - lr: 1.0108547030540649e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.8996 - loss: 0.2505 - precision_3: 0.8996 - recall_3: 0.8996 - val_accuracy: 0.7849 - val_loss: 0.7717 - val_precision_3: 0.7849 - val_recall_3: 0.7849
# Epoch 299/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8928 - loss: 0.2529 - precision_3: 0.8928 - recall_3: 0.8928 - lr: 1.0027144526247866e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8928 - loss: 0.2529 - precision_3: 0.8928 - recall_3: 0.8928 - val_accuracy: 0.7928 - val_loss: 0.7779 - val_precision_3: 0.7928 - val_recall_3: 0.7928
# Epoch 300/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8907 - loss: 0.2606 - precision_3: 0.8907 - recall_3: 0.8907 - lr: 1.0000000656873453e-05
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.8908 - loss: 0.2604 - precision_3: 0.8908 - recall_3: 0.8908 - val_accuracy: 0.7829 - val_loss: 0.7829 - val_precision_3: 0.7829 - val_recall_3: 0.7829

# %%
fig, axs = plt.subplots(2,1, figsize=(6, 10))
    
# Subplot 1: Plot training & validation accuracy values
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy ' + model_name)

axs[0].axhline(y=max(history.history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.93, f'Max Acc: {max(history.history["accuracy"])}', color='b')  # Add text annotation with the max value

axs[0].axhline(y=max(history.history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[0].text(50,0.83, f'Max Val Acc: {max(history.history["val_accuracy"])}', color='red')  # Add text annotation with the max value
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend(['Train', 'Val'], loc='upper left')
axs[0].set_ylim(0.5, 1)

# Subplot 2: Plot training & validation loss values
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss ' + model_name)
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['Train', 'Val'], loc='upper left')
axs[1].set_ylim(0, 1)

axs[1].axhline(y=min(history.history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.45, f'Min Val loss: {min(history.history["val_loss"])}', color='red')  # Add text annotation with the max value

axs[1].axhline(y=min(history.history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
axs[1].text(50,0.1, f'Min loss: {min(history.history["loss"])}', color='b')  # Add text annotation with the max value

# Save the figure with subplots
plt.savefig(f'{plot_folder}\\ACC_LOSS_{model_name}.png')

# Show the plot
plt.show()

# %%
#import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical

# Assuming y_val is one-hot encoded, convert it back to class labels
y_true_classes = np.argmax(val_labels_categorical, axis=1)

# Make predictions on the validation set
y_pred = model.predict(val_data)

# Convert predictions from sigmoid output to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
cmap = plt.cm.Blues
plt.imshow(cm, interpolation='nearest', cmap=cmap)
plt.title('Confusion Matrix ' + model_name)
plt.colorbar()
tick_marks = np.arange(len(np.unique(y_true_classes)))  # this adapts to the number of classes dynamically
plt.xticks(tick_marks, tick_marks)
plt.yticks(tick_marks, tick_marks)

# Labeling the axes
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations inside the squares
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.savefig(f'{plot_folder}\\CM_{model_name}.png')

plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
mm.save_model(model, model_folder, model_name)
# Out:
# Model saved to .\MODELS_6337\M_1_6337.keras

# %%
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
print('training time:', (training_time/60), 'minutes')
# Convert the history object to a dictionary
history_dict = history.history

# Add the training time to the dictionary
history_dict['training_time'] = training_time
history_dict['model'] = model_name
history_dict['batch_size'] = batch_size
history_dict['epochs'] = epochs
history_dict['learning_rate'] = initial_learning_rate
history_dict['decay_steps'] = decay_steps
history_dict['alpha'] = alpha
history_dict['loss_function'] = 'binary_crossentropy'
history_dict['optimizer'] = 'Adam'

# Save the dictionary to a JSON file
mm.save_history(history_dict, model_folder, model_name)
# Out:
# Training time: 1249.6577022075653 seconds
# training time: 20.82762837012609 minutes
# History saved to .\MODELS_6337\M_1_6337_history.json

# %%
print('output shape')
print(y_pred.shape)
print('output')
print(y_pred)
# Out:
# output shape
# (502, 2)
# output
# [[1.91418675e-03 9.98085856e-01]
#  [3.92831280e-05 9.99960661e-01]
#  [8.95367877e-11 1.00000000e+00]
#  ...
#  [9.98865366e-01 1.13462226e-03]
#  [8.84000897e-01 1.15999125e-01]
#  [9.96666253e-01 3.33379698e-03]]

# %% [markdown]
# ## changing axis

# %%
models = ['M_1_6337']

# %%
for model in models:
    #m = tf.keras.models.load_model(f'.\\MODELS\\{model}.keras')
    m = mm.load_model(model_folder, model)
    history = mm.load_history(model_folder, model)
    fig, axs = plt.subplots(2,1, figsize=(6, 10))
        
    # Subplot 1: Plot training & validation accuracy values
    axs[0].plot(history['accuracy'])
    axs[0].plot(history['val_accuracy'])
    axs[0].set_title('Model Accuracy ' + model)

    axs[0].axhline(y=max(history['accuracy']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.93, f'Max Acc: {max(history["accuracy"])}', color='b')  # Add text annotation with the max value

    axs[0].axhline(y=max(history['val_accuracy']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[0].text(50,0.83, f'Max Val Acc: {max(history["val_accuracy"])}', color='red')  # Add text annotation with the max value
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Val'], loc='upper left')
    axs[0].set_ylim(0.5, 1)

    # Subplot 2: Plot training & validation loss values
    axs[1].plot(history['loss'])
    axs[1].plot(history['val_loss'])
    axs[1].set_title('Model Loss ' + model)
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Val'], loc='upper left')
    axs[1].set_ylim(0, 1)

    axs[1].axhline(y=min(history['val_loss']), color='r', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.45, f'Min Val loss: {min(history["val_loss"])}', color='red')  # Add text annotation with the max value

    axs[1].axhline(y=min(history['loss']), color='b', linestyle='--')  # Add horizontal line at y=0.75
    axs[1].text(50,0.1, f'Min loss: {min(history["loss"])}', color='b')  # Add text annotation with the max value

    # Save the figure with subplots
    #plt.savefig(f'{plot_folder}\\ACC_LOSS_{model}.png')

    # Show the plot
    plt.show()
# Out:
# Loading model from .\MODELS_6337\M_1_6337.keras
# Num Layers: 9
# ----
# ----
# Layer: conv1d_2
# {
#     "name": "conv1d_2",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "filters": 16,
#     "kernel_size": [
#         10
#     ],
#     "strides": [
#         1
#     ],
#     "padding": "valid",
#     "data_format": "channels_last",
#     "dilation_rate": [
#         1
#     ],
#     "groups": 1,
#     "activation": "relu",
#     "use_bias": true,
#     "kernel_initializer": {
#         "module": "keras.initializers",
#         "class_name": "GlorotUniform",
#         "config": {
#             "seed": null
#         },
#         "registered_name": null
#     },
#     "bias_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "kernel_regularizer": null,
#     "bias_regularizer": null,
#     "activity_regularizer": null,
#     "kernel_constraint": null,
#     "bias_constraint": null
# }
# ----
# ----
# Layer: batch_normalization_2
# {
#     "name": "batch_normalization_2",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "axis": -1,
#     "momentum": 0.99,
#     "epsilon": 0.001,
#     "center": true,
#     "scale": true,
#     "beta_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "gamma_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Ones",
#         "config": {},
#         "registered_name": null
#     },
#     "moving_mean_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "moving_variance_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Ones",
#         "config": {},
#         "registered_name": null
#     },
#     "beta_regularizer": null,
#     "gamma_regularizer": null,
#     "beta_constraint": null,
#     "gamma_constraint": null,
#     "synchronized": false
# }
# ----
# ----
# Layer: max_pooling1d_1
# {
#     "name": "max_pooling1d_1",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "pool_size": [
#         2
#     ],
#     "padding": "valid",
#     "strides": [
#         2
#     ],
#     "data_format": "channels_last"
# }
# ----
# ----
# Layer: conv1d_3
# {
#     "name": "conv1d_3",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "filters": 32,
#     "kernel_size": [
#         10
#     ],
#     "strides": [
#         1
#     ],
#     "padding": "valid",
#     "data_format": "channels_last",
#     "dilation_rate": [
#         1
#     ],
#     "groups": 1,
#     "activation": "relu",
#     "use_bias": true,
#     "kernel_initializer": {
#         "module": "keras.initializers",
#         "class_name": "GlorotUniform",
#         "config": {
#             "seed": null
#         },
#         "registered_name": null
#     },
#     "bias_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "kernel_regularizer": null,
#     "bias_regularizer": null,
#     "activity_regularizer": null,
#     "kernel_constraint": null,
#     "bias_constraint": null
# }
# ----
# ----
# Layer: batch_normalization_3
# {
#     "name": "batch_normalization_3",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "axis": -1,
#     "momentum": 0.99,
#     "epsilon": 0.001,
#     "center": true,
#     "scale": true,
#     "beta_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "gamma_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Ones",
#         "config": {},
#         "registered_name": null
#     },
#     "moving_mean_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "moving_variance_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Ones",
#         "config": {},
#         "registered_name": null
#     },
#     "beta_regularizer": null,
#     "gamma_regularizer": null,
#     "beta_constraint": null,
#     "gamma_constraint": null,
#     "synchronized": false
# }
# ----
# ----
# Layer: global_average_pooling1d_1
# {
#     "name": "global_average_pooling1d_1",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "data_format": "channels_last",
#     "keepdims": false
# }
# ----
# ----
# Layer: dropout_1
# {
#     "name": "dropout_1",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "rate": 0.2,
#     "seed": null,
#     "noise_shape": null
# }
# ----
# ----
# Layer: dense_2
# {
#     "name": "dense_2",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "units": 32,
#     "activation": "relu",
#     "use_bias": true,
#     "kernel_initializer": {
#         "module": "keras.initializers",
#         "class_name": "GlorotUniform",
#         "config": {
#             "seed": null
#         },
#         "registered_name": null
#     },
#     "bias_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "kernel_regularizer": null,
#     "bias_regularizer": null,
#     "kernel_constraint": null,
#     "bias_constraint": null
# }
# ----
# ----
# Layer: dense_3
# {
#     "name": "dense_3",
#     "trainable": true,
#     "dtype": {
#         "module": "keras",
#         "class_name": "DTypePolicy",
#         "config": {
#             "name": "float32"
#         },
#         "registered_name": null
#     },
#     "units": 2,
#     "activation": "softmax",
#     "use_bias": true,
#     "kernel_initializer": {
#         "module": "keras.initializers",
#         "class_name": "GlorotUniform",
#         "config": {
#             "seed": null
#         },
#         "registered_name": null
#     },
#     "bias_initializer": {
#         "module": "keras.initializers",
#         "class_name": "Zeros",
#         "config": {},
#         "registered_name": null
#     },
#     "kernel_regularizer": null,
#     "bias_regularizer": null,
#     "kernel_constraint": null,
#     "bias_constraint": null
# }
# ----
# History loaded from .\MODELS_6337\M_1_6337_history.json
